# %%
import numpy as np
import math
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

global scaling_factor; scaling_factor = 10000 #scaling_factor for OR tools to deal with it only being able to handle integers 

def compute_euclidean_distance_matrix(locations):
    global scaling_factor; 
    """Creates callback to return distance between points."""
    distances = {}
    for from_counter, from_node in enumerate(locations):
        distances[from_counter] = {}
        for to_counter, to_node in enumerate(locations):
            if from_counter == to_counter:
                distances[from_counter][to_counter] = 0
            else:
                # Euclidean distance
                distances[from_counter][to_counter] = (scaling_factor*(
                    math.hypot((from_node[0] - to_node[0]),
                               (from_node[1] - to_node[1])))) 
    return distances


def print_solution(manager, routing, solution, print_sol = False):
    """Prints solution on console."""
    global scaling_factor
    
    cost = solution.ObjectiveValue()/scaling_factor
    
    #print('Objective: {}'.format(cost))
    index = routing.Start(0)
    plan_output = 'Route:\n'
    route_distance = 0
    array_best_path = []
    
    while not routing.IsEnd(index):
        plan_output += ' {} ->'.format(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        array_best_path.append(previous_index)
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    
    if print_sol: 
        plan_output += ' {}\n'.format(manager.IndexToNode(index))
        print(plan_output)
        plan_output += 'Objective: {}m\n'.format(route_distance)
        #print('Best path array: ', array_best_path)
    
    return array_best_path, cost

def solve_tsp_with_ortools(locations):
    global scaling_factor; 
    """Entry point of the program."""
    # Instantiate the data dictionary. 
    data = {'locations': locations, 'num_vehicles': 1, 'depot': 0}

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['locations']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)

    distance_matrix = compute_euclidean_distance_matrix(data['locations'])

    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return distance_matrix[from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        array_best_path, cost = print_solution(manager, routing, solution)

        return array_best_path, cost

#Solve with TD learning

def euclidean_dist(x,y):
    return ((locations[x][0]-locations[y][0])**2+ (locations[x][1]-locations[y][1])**2)**0.5

def path_cost(path):
    cost = 0 
    for i in range(1, len(path)): 
        cost+=euclidean_dist(path[i], path[i-1])
    cost+=euclidean_dist(path[-1], path[0])
    return cost 

def solve_tsp_with_td_learning(locations): 
    
    #define training parameters
    epsilon = 1 #the percentage of time when we should take a random action 
    discount_factor = 1 #discount factor for future rewards
    learning_rate = 0.1 #the rate at which the AI agent should learn
      
    q_values = np.zeros((len(locations), len(locations)))
 
    depot = 0 
    
    n_training_episodes = 1000 
    
    for episode in range(n_training_episodes): 
        current_state = depot  
        possible_next_states = [i for i in range(1, len(locations))] #next state to visit; depot must be 0 for this to work  
        
        while possible_next_states:  
            
            if np.random.random() < epsilon:
                next_state = np.random.choice(possible_next_states)  #pick random action with probability epsilon  
            else:  
                next_state = possible_next_states[np.argmax(q_values[current_state, possible_next_states])] 
                 
            possible_next_states.remove(next_state) 
                 
            reward = -euclidean_dist(current_state, next_state) #aim is to maximize reward 
               
            q_values[current_state, next_state] += learning_rate*(reward + discount_factor * max(q_values[next_state]) - q_values[current_state, next_state])
            #max(q_values[action, possible_next_states]) instead max(q_values[action]) generates unstable results 
            
            current_state = next_state
            
        q_values[current_state, depot] += learning_rate*(reward -  q_values[current_state, depot]) #terminal state update 
             
        epsilon = 1-episode/n_training_episodes #gradual decay 
        
    #print('q_values: ', q_values)
    
    optimal_path = [depot]
    current_state = depot 
    
    possible_next_states = [i for i in range(1, len(locations))]
    
    while possible_next_states:  
        next_loc = possible_next_states[np.argmax(q_values[current_state, possible_next_states])] 
        current_state = next_loc 
        possible_next_states.remove(next_loc) 
        optimal_path.append(next_loc)
      
    cost = path_cost(optimal_path)
    
    #print('optimal_path with TD learning: ', optimal_path); print('cost with TD learning: ', cost) 
     
    return optimal_path, cost  
  
if __name__ == '__main__':
    
    # Set the print options to automatically round to 4 decimal places
    np.set_printoptions(precision=4, suppress=True)
     
    # Generate a range of instances and compare the approximate solution with optimal solution
    num_instances = 100 
    total_accuracy = 0

    for i in range(num_instances):
        # Generate a random instance with random locations
        num_cities = np.random.randint(5, 10)
        locations = [(np.random.uniform(0, 10), np.random.uniform(0, 10)) for _ in range(num_cities)]
         
        print(f"\n\nInstance {i+1}:")
        print('locations: ', locations) 
        
        # Solve TSP using OR-Tools 
        or_tools_path, or_tools_path_cost = solve_tsp_with_ortools(locations)
          
        td_learning_path, td_learning_path_cost = solve_tsp_with_td_learning(locations)

        # Calculate the accuracy of the TD learning solution 
        if td_learning_path_cost > or_tools_path_cost: 
            accuracy = (1 - (abs(td_learning_path_cost - or_tools_path_cost) / or_tools_path_cost)) * 100 #percentage 
        else:
            accuracy = 100 #percentage 
            
        total_accuracy += accuracy

        # Print the results for each instance 
        print("Tour found with TD learning:", td_learning_path)
        print("TD learning Tour Cost:", td_learning_path_cost)
        print("Tour found with OR Tools:", or_tools_path)
        print("OR Tools Tour Cost:", or_tools_path_cost)
        print("Accuracy:", accuracy)
        print()

    # Print the average accuracy across all instances
    average_accuracy = total_accuracy / num_instances
    print("Average Percent Accuracy:", average_accuracy)
# Out:
# Instance 1:
# locations:  [(5.526484645411359, 3.0383026018012305), (2.8038550485435234, 0.4952993952097451), (6.780694299215856, 2.428100493714096), (3.49722351064747, 6.061533849500145), (3.0541451920262563, 9.169413317184485)]
# Tour found with TD learning: [0, 2, 1, 3, 4]
# TD learning Tour Cost: 21.175800951412636
# Tour found with TD learning: [0, 8, 3, 4, 1, 6, 5, 7, 2]
# TD learning Tour Cost: 27.87030815353633
# Tour found with OR Tools: [0, 8, 3, 4, 2, 7, 5, 6, 1]
# OR Tools Tour Cost: 26.5866
# Accuracy: 95.17159714466563
#
#
#
# Instance 13:
# locations:  [(7.735527218512743, 1.197497113225915), (7.348367021965702, 8.986985618439764), (0.881135523715636, 5.486749875685347), (9.289367217120928, 3.8473702879826046), (2.5874008624220246, 4.528968592588354), (8.550588135785194, 4.536630508195664), (1.9862932854241633, 3.5914712166064033), (2.9543565212784917, 1.791139753569574)]
# Tour found with TD learning: [0, 3, 5, 1, 4, 6, 7, 2]
# TD learning Tour Cost: 30.695430092943283
# Tour found with OR Tools: [0, 3, 5, 1, 2, 4, 6, 7]
# OR Tools Tour Cost: 25.9776
# Accuracy: 81.83885311597959
#
#
#
# Instance 14:
# locations:  [(7.5204705210551746, 3.7646537616546993), (5.656849986993534, 5.793677557554551), (1.6613971646267656, 7.087540477034301), (2.702439311913516, 6.587078290289956), (9.168067994519374, 8.719168126945341), (7.775375286453866, 0.4968513038124167)]
# Tour found with TD learning: [0, 1, 3, 2, 4, 5]
# TD learning Tour Cost: 26.2682837725355
# Tour found with OR Tools: [0, 4, 2, 3, 1, 5]
# OR Tools Tour Cost: 26.0995
# Accuracy: 99.35330649040978
#
#
#
# Instance 15:
# locations:  [(9.563701543952043, 9.883408008444533), (1.9039233138545442, 9.463578901622764), (6.282332709691537, 9.986897773726152), (8.232447842931698, 0.8632938450875316), (3.9329232417050752, 9.13059320878531)]
# Tour found with TD learning: [0, 2, 4, 1, 3]
# TD learning Tour Cost: 27.635348391468867
# Tour found with OR Tools: [0, 2, 4, 1, 3]
# OR Tools Tour Cost: 27.6351
# Accuracy: 99.99910117398213
#
#
#
# Instance 16:
# locations:  [(5.532245337690739, 4.759818894376078), (1.0839801060092447, 5.507562479938498), (1.824222959402202, 4.298153118323804), (3.6568687902101704, 8.194086434351078), (1.8645688248090397, 7.499443522570339), (9.117067096819419, 3.0708723246641267), (5.1964145474275885, 0.7920659785881023)]
# Tour found with TD learning: [0, 2, 1, 4, 3, 5, 6]
# TD learning Tour Cost: 25.220335939110413
# Tour found with OR Tools: [0, 5, 6, 2, 1, 4, 3]
# OR Tools Tour Cost: 22.7543
# Accuracy: 89.16233002504839
#
#
#
# Instance 17:
# locations:  [(6.342227511865627, 2.727096833978865), (3.7537802163876712, 5.298308141280339), (1.1230559473269974, 3.88105409054188), (1.3610389522573896, 8.511041481075099), (2.8043533452893032, 9.776284391101623), (3.0655988961151257, 8.394900539513584)]
# Tour found with TD learning: [0, 1, 2, 3, 5, 4]
# TD learning Tour Cost: 22.274307616857495
# Tour found with OR Tools: [0, 1, 5, 4, 3, 2]
# OR Tools Tour Cost: 20.1268
# Accuracy: 89.3301090244972
#
#
#
# Instance 18:
# locations:  [(1.7958497202745338, 7.804171508999715), (6.721592736424543, 4.124768940515253), (8.445513508976571, 4.118911339467964), (0.8650353901443042, 3.8919974037892855), (3.1462211464628496, 3.7234277984900266), (2.9043537800777464, 6.874232595445484), (7.960956066359193, 2.283969983281403), (3.375718191710151, 6.656877721225166)]
# Tour found with TD learning: [0, 5, 7, 4, 3, 1, 2, 6]
# TD learning Tour Cost: 24.9540887146891
# Tour found with OR Tools: [0, 5, 7, 1, 2, 6, 4, 3]
# OR Tools Tour Cost: 21.1176
# Accuracy: 81.83274276106613
#
#
#
# Instance 19:
# locations:  [(6.07047376662466, 3.5499106832280045), (9.654024388811381, 3.782650925712119), (2.8161632209770393, 5.292547072352183), (5.018665550464498, 5.690289864813215), (4.390212850880847, 3.4589479020822966), (0.3789880935930712, 0.4667356805389222)]
# Tour found with TD learning: [0, 4, 3, 2, 5, 1]
# TD learning Tour Cost: 25.08637625316664
# Tour found with OR Tools: [0, 4, 5, 2, 3, 1]
# OR Tools Tour Cost: 22.935
# Accuracy: 90.61968060533403
#
#
#
# Instance 20:
# locations:  [(9.030921610793817, 3.3487152374348805), (5.2005321953427455, 4.540207557666186), (4.608376958764358, 5.733854116601526), (9.098741591704908, 1.421089518850831), (2.453663615298358, 3.7217463368715045), (5.697776918467808, 8.642905463965784), (8.06457483832224, 5.560184792013646), (2.4408723343684704, 5.794667201560378), (4.295155507059219, 1.3478108233320363)]
# Tour found with TD learning: [0, 3, 6, 1, 2, 7, 4, 8, 5]
# TD learning Tour Cost: 31.498386041929937
# Tour found with OR Tools: [0, 3, 8, 4, 7, 1, 2, 5, 6]
# OR Tools Tour Cost: 25.5801
# Accuracy: 76.86371029851355
#
#
#
# Instance 21:
# locations:  [(1.5424875029869944, 0.9505355445515462), (3.369795598737033, 6.322924284950794), (3.129414995566991, 8.557148746172711), (0.5924669746696831, 9.766327790428422), (0.044099096412169025, 9.405835977014886), (0.584247686155035, 7.9359406236932095)]
# Tour found with TD learning: [0, 1, 2, 5, 4, 3]
# TD learning Tour Cost: 21.630726666460333
# Tour found with OR Tools: [0, 1, 2, 3, 4, 5]
# OR Tools Tour Cost: 20.0049
# Accuracy: 91.87285781753303
#
#
#
# Instance 22:
# locations:  [(4.558558632872421, 0.9137759841769633), (8.496104730332444, 9.22991914018515), (6.706459528788208, 3.8077090035224694), (5.216443731924509, 1.805592626756315), (2.3469581542723716, 4.102833893201227)]
# Tour found with TD learning: [0, 3, 2, 4, 1]
# TD learning Tour Cost: 25.18082701377849
# Tour found with OR Tools: [0, 3, 2, 1, 4]
# OR Tools Tour Cost: 21.2007
# Accuracy: 81.22643585457797
#
#
#
# Instance 23:
# locations:  [(1.1476333967470087, 6.564253504270088), (3.913390312107171, 1.6392264608229312), (4.829568313937825, 5.900221896727609), (3.1064047578834266, 3.1312661170696474), (1.816013470766259, 6.592022824419529)]
# Tour found with TD learning: [0, 4, 2, 3, 1]
# TD learning Tour Cost: 14.367019143417632
# Tour found with OR Tools: [0, 4, 2, 1, 3]
# OR Tools Tour Cost: 13.7677
# Accuracy: 95.64691892314887
#
#
#
# Tour found with TD learning: [0, 1, 3, 4, 5, 2]
# TD learning Tour Cost: 16.772659766268127
# Tour found with OR Tools: [0, 1, 2, 5, 4, 3]
# OR Tools Tour Cost: 16.0459
# Accuracy: 95.47074476178882
#
#
#
# Instance 41:
# locations:  [(2.750147153224438, 6.5430861380776495), (3.3601106105120837, 9.878738663952968), (1.0698821505417777, 1.110435632486274), (5.475153601512512, 0.19152412903868377), (0.09446582764209066, 6.259983642242802)]
# Tour found with TD learning: [0, 4, 1, 2, 3]
# TD learning Tour Cost: 28.019129427703277
# Tour found with OR Tools: [0, 3, 2, 4, 1]
# OR Tools Tour Cost: 24.9178
# Accuracy: 87.55375904893981
#
#
#
# Instance 42:
# locations:  [(3.481163014851637, 8.738076358909924), (5.092404075075714, 3.2508711978842273), (3.3777310669612213, 7.430551518511473), (7.619282868657772, 0.9357486560003425), (9.115854392282964, 9.32367122166568), (1.3007060561556805, 4.637066559996635), (2.413078782610789, 5.702885256134207), (0.7991915938318583, 2.8739988146821682), (6.207721994407694, 7.833269685065605)]
# Tour found with TD learning: [0, 2, 6, 5, 7, 1, 3, 8, 4]
# TD learning Tour Cost: 30.374041970241112
# Tour found with OR Tools: [0, 2, 6, 5, 7, 1, 3, 4, 8]
# OR Tools Tour Cost: 29.0613
# Accuracy: 95.48285186746253
#
#
#
# Instance 43:
# locations:  [(0.12106236858852926, 6.283373537917703), (2.2729741036554527, 8.284657214205748), (8.477777651381263, 9.268755690641775), (7.282773807821478, 0.1968914765596852), (7.795711946595487, 9.022891448516798), (4.588395256002573, 7.522268099313223)]
# Tour found with TD learning: [0, 1, 5, 4, 2, 3]
# TD learning Tour Cost: 28.191348303978955
# Tour found with OR Tools: [0, 1, 5, 4, 2, 3]
# OR Tools Tour Cost: 28.1911
# Accuracy: 99.99911921145697
#
#
#
# Instance 44:
# locations:  [(7.458261615887011, 0.8001964771356651), (6.74375993286502, 6.294643621732041), (5.1773679035447815, 4.219681476296165), (1.4893314614018394, 0.826493682722228), (6.414595248906634, 0.049730653737021235), (9.626956424588771, 9.030845612308196), (9.371122800881352, 9.553961368037868)]
# Tour found with TD learning: [0, 4, 2, 1, 5, 6, 3]
# TD learning Tour Cost: 30.520831972301863
# Tour found with OR Tools: [0, 4, 3, 2, 1, 6, 5]
# OR Tools Tour Cost: 27.163
# Accuracy: 87.63821384861075
#
#
#
# Instance 45:
# locations:  [(9.906241024305798, 3.632169563381277), (5.946515119686189, 9.372261104440302), (4.146730490398532, 7.199869792531407), (0.9776332563027634, 6.682018598842668), (0.32158549493356947, 9.317449841672246), (4.804440009910834, 7.117713223259335), (4.900653663512217, 5.934383959039384), (0.8704048855038948, 0.7273686297279836), (1.211897560642382, 3.6553435484177657)]
# Tour found with TD learning: [0, 6, 5, 2, 1, 4, 3, 8, 7]
# TD learning Tour Cost: 33.996650875808925
# Tour found with OR Tools: [0, 6, 2, 5, 1, 4, 3, 8, 7]
# locations:  [(6.331707886036378, 6.061386986596698), (2.855264087720062, 5.960591551482683), (3.4707969588624312, 4.713785589174155), (1.9552765570000874, 7.353634478926459), (8.689524724743569, 6.062377680921383)]
# Tour found with TD learning: [0, 4, 2, 1, 3]
# TD learning Tour Cost: 15.360151855896124
# Tour found with OR Tools: [0, 4, 2, 1, 3]
# OR Tools Tour Cost: 15.3599
# Accuracy: 99.99836030250117
#
#
#
# Instance 52:
# locations:  [(6.10171116899641, 0.9358805823600813), (2.5009158343718663, 9.344699817510238), (7.716021390236238, 1.6686439141071407), (0.6613301210567668, 6.478949330227131), (2.647652838444202, 6.0086502379859255), (9.727408964242205, 0.7194841402950292), (5.606296598180554, 7.643876125463676)]
# Tour found with TD learning: [0, 2, 5, 6, 4, 3, 1]
# TD learning Tour Cost: 30.02931827389449
# Tour found with OR Tools: [0, 2, 5, 6, 1, 3, 4]
# OR Tools Tour Cost: 27.1788
# Accuracy: 89.5119789177797
#
#
#
# Instance 53:
# locations:  [(3.994129300818794, 2.540572819908257), (6.549997546970776, 5.496468390216672), (0.30290581653000914, 5.522279129191634), (9.11013421586791, 5.388070299663509), (2.35554359113015, 0.5623918077829804)]
# Tour found with TD learning: [0, 4, 2, 1, 3]
# TD learning Tour Cost: 22.60117540109809
# Tour found with OR Tools: [0, 4, 2, 1, 3]
# OR Tools Tour Cost: 22.6009
# Accuracy: 99.99878145959634
#
#
#
# Instance 54:
# locations:  [(9.80644542572498, 2.6773420065575304), (7.574175810768443, 9.412208261593667), (5.493944949793756, 8.859766526701435), (3.2346287020216224, 6.860285240431895), (1.2346996485876083, 6.66976650776826), (5.569685857383812, 0.8551128756097726), (3.182558783917815, 0.8456527204086184), (2.150037972246732, 1.4478174403888378), (6.2156736354608295, 2.4203078014402815)]
# Tour found with TD learning: [0, 8, 5, 6, 7, 4, 3, 2, 1]
# TD learning Tour Cost: 28.450730538458316
# Tour found with OR Tools: [0, 8, 5, 6, 7, 4, 3, 2, 1]
# OR Tools Tour Cost: 28.4502
# Accuracy: 99.99813520306249
#
#
#
# Instance 55:
# locations:  [(7.902843281363076, 8.845726321627621), (6.270864793996428, 0.27696049902011577), (6.898803333890919, 5.562241717215947), (7.233308549830674, 5.550421553708476), (4.321215495316501, 5.367052432076562), (2.8551974036475567, 0.4624612629874503), (7.114452388167569, 5.543019590124843)]
# Tour found with TD learning: [0, 3, 6, 2, 4, 5, 1]
# TD learning Tour Cost: 23.545691608945088
# Tour found with OR Tools: [0, 4, 5, 1, 2, 6, 3]
# OR Tools Tour Cost: 22.5531
# Accuracy: 95.59886840857759
#
#
#
# Instance 56:
# locations:  [(8.978150098073147, 9.510081657162084), (0.8720900651378416, 0.8444517327466672), (0.6732006190725903, 8.222367163425888), (4.90213232113279, 5.179195379697035), (3.1204498466255313, 1.663681473318045), (1.2503848320867816, 8.888479356024948), (6.045617367854793, 9.785921124042979), (9.336400197707476, 1.0254642597787167), (4.039016761581447, 0.04929771694238472)]
# Tour found with TD learning: [0, 6, 3, 4, 8, 1, 2, 5, 7]
# TD learning Tour Cost: 44.788796915188826
# Tour found with OR Tools: [0, 6, 5, 2, 1, 4, 8, 7, 3]
# OR Tools Tour Cost: 37.7455
# Accuracy: 81.34003546068054
#
#
#
# Instance 57:
# locations:  [(9.765714599835302, 9.261693850139064), (9.929166789404164, 2.5727167149353383), (9.575290640770866, 7.751636915560306), (9.95542601201317, 8.553768626604874), (9.494072386917257, 4.053680126502622), (1.2551558985769506, 8.331412344114973)]
# Tour found with TD learning: [0, 3, 2, 4, 1, 5]
# TD learning Tour Cost: 25.835788449744783
# Tour found with OR Tools: [0, 3, 2, 4, 1, 5]
# OR Tools Tour Cost: 25.8355
# Accuracy: 99.99888351398354
#
#
#
# Instance 58:
# locations:  [(7.7163280981335705, 5.095870947071596), (1.1282992477960485, 0.10004496049264011), (4.136620176165472, 9.284295292646023), (8.754007519849626, 8.462102658823094), (8.68581479770587, 1.5793555667880377), (4.777526903759926, 6.902436221912192)]
# Tour found with TD learning: [0, 5, 2, 3, 4, 1]
# TD learning Tour Cost: 33.45832317238737
# Tour found with OR Tools: [0, 3, 2, 5, 1, 4]
# OR Tools Tour Cost: 29.747
# Accuracy: 87.52370601274964
#
#
#
# Instance 59:
# locations:  [(7.471249190215356, 5.663529688531346), (7.663157099265367, 0.004978302256276601), (6.744743579235097, 7.454236811293505), (4.866539316446669, 2.8688831801921975), (2.4083895499728047, 2.338144371304888), (6.9768432237014615, 4.6812403359891555), (9.060009655513486, 0.3839222422163313), (1.932992984851154, 6.771355227106111), (7.497336501656015, 4.923085169506064)]
# Tour found with TD learning: [0, 8, 5, 3, 4, 7, 2, 6, 1]
# TD learning Tour Cost: 30.478846824062945
# Tour found with OR Tools: [0, 2, 7, 4, 3, 1, 6, 5, 8]
# OR Tools Tour Cost: 25.3061
# Accuracy: 79.55928877202356
#
#
#
# Instance 60:
# locations:  [(3.739567131406308, 8.487444208933882), (8.613786885950764, 5.09281306448159), (7.068835517313424, 6.112121307320728), (7.1305107170063176, 9.637320996032404), (4.7548209650284186, 0.34159311777295254), (1.7948472959105488, 5.578047069896996), (8.435053707491907, 9.879213343343261), (9.743899541240676, 3.463926869786903)]
# Tour found with TD learning: [0, 5, 2, 1, 7, 4, 3, 6]
# TD learning Tour Cost: 34.3381586798673
# Tour found with OR Tools: [0, 5, 4, 7, 1, 2, 6, 3]
# OR Tools Tour Cost: 28.1479
# Accuracy: 78.0080976560692
#
#
#
# Instance 61:
# locations:  [(8.572551417214939, 2.178507889032365), (1.8446869382797382, 2.600741757315226), (0.3673433921240121, 2.963439423680315), (0.6704732325164631, 9.49291274761868), (6.9439492400962965, 0.7376933048979639), (4.620697992998871, 7.3628905844894845), (6.019758056127291, 0.3095165845966763), (7.880943690176617, 4.3862195400531245)]
# Tour found with TD learning: [0, 4, 6, 7, 5, 3, 2, 1]
# TD learning Tour Cost: 31.37593379968099
# Tour found with OR Tools: [0, 4, 6, 1, 2, 3, 5, 7]
# OR Tools Tour Cost: 27.2291
# Accuracy: 84.77058074016037
#
#
#
# Instance 62:
# locations:  [(3.471631804053694, 0.008843342304419854), (2.4783580761540183, 2.532948886080142), (0.16389671068720357, 6.846428185470716), (9.66142150580899, 3.78326765681132), (9.199588135508941, 3.748398500292185), (9.337384993034046, 7.548128872069593)]
# Tour found with TD learning: [0, 1, 2, 5, 3, 4]
# TD learning Tour Cost: 27.890503922914142
# Tour found with OR Tools: [0, 1, 2, 5, 3, 4]
# OR Tools Tour Cost: 27.8901
# Accuracy: 99.99855173371863
#
#
#
# Instance 63:
# locations:  [(1.456715079296329, 0.3401449999620598), (5.076813317238057, 6.051312200597656), (0.43574425201504674, 4.874922129743514), (3.713817610195571, 9.621146509786495), (2.5270027359029035, 4.38441644854206), (6.674417537468287, 9.63147614578512)]
# Tour found with TD learning: [0, 4, 2, 1, 3, 5]
# TD learning Tour Cost: 28.55729233142784
# Tour found with OR Tools: [0, 2, 3, 5, 1, 4]
# OR Tools Tour Cost: 24.5271
# Accuracy: 83.56841073168928
#
#
#
# Instance 64:
# locations:  [(7.961645379923004, 7.823717700783886), (5.358614647402975, 5.264457364528129), (5.691565576745586, 5.368562877220341), (2.649973280399359, 9.817393876041482), (0.9802842078987206, 9.429299846889798), (8.589039146297994, 3.9995561074477095), (5.256907183822736, 6.23453553834473), (7.745456807111019, 1.8857012168024845), (5.225990597576172, 0.6990632518074036)]
# Tour found with TD learning: [0, 6, 2, 1, 5, 7, 8, 3, 4]
# TD learning Tour Cost: 31.337997003879412
# Tour found with OR Tools: [0, 5, 7, 8, 1, 2, 6, 4, 3]
# OR Tools Tour Cost: 27.5467
# Accuracy: 86.23683779226037
#
#
#
# Instance 65:
# locations:  [(1.111259975448513, 0.2046930193671459), (9.015026611887139, 4.156539568531647), (5.700005347206702, 5.723677451884849), (0.8948345810645908, 7.568405104899908), (3.531115930113656, 8.609344234904908), (8.456861384741167, 0.5716702521231953), (8.417301560153836, 5.617696156693082)]
# Tour found with TD learning: [0, 2, 6, 1, 5, 4, 3]
# TD learning Tour Cost: 34.73174019904817
# Tour found with OR Tools: [0, 5, 1, 6, 2, 4, 3]
# OR Tools Tour Cost: 29.0915
# Accuracy: 80.61206813313797
#
#
#
# Instance 66:
# locations:  [(9.955601906795026, 8.864845363740987), (5.811521787644959, 0.47404467300241837), (4.682436018393883, 2.847430239124197), (7.571908459923311, 7.703690955930032), (2.5980056289903084, 7.933005932218384), (3.71484127603959, 0.03679294761467666), (9.27417904465967, 6.876663326515602), (0.04001949039020736, 2.871948925789253), (5.400021816820679, 7.8164735803927465)]
# Tour found with TD learning: [0, 6, 3, 8, 4, 2, 1, 5, 7]
# TD learning Tour Cost: 35.4670384213283
# Tour found with OR Tools: [0, 6, 2, 1, 5, 7, 4, 8, 3]
# OR Tools Tour Cost: 30.9231
# Accuracy: 85.30568273773233
#
#
#
# Instance 67:
# locations:  [(2.942012821197577, 7.547147443703564), (5.807596821664224, 4.4050987254461935), (4.299802713961639, 0.6778406941105286), (8.405088496337996, 8.521643212931064), (1.762408146791794, 4.340607846376871), (3.2603976097362874, 7.1734659519489155)]
# Tour found with TD learning: [0, 5, 4, 1, 2, 3]
# TD learning Tour Cost: 26.164326681207072
# Tour found with OR Tools: [0, 5, 3, 1, 2, 4]
# OR Tools Tour Cost: 22.5698
# Accuracy: 84.0737326816938
#
#
#
# Instance 68:
# locations:  [(7.123243990571385, 3.632986530115021), (6.2383118248638105, 3.6336861565916365), (5.037387408901005, 5.958829426821843), (4.188182808891131, 5.776991106347651), (5.813035992885877, 3.5304976931945875), (0.32671462831066034, 5.135268144941737)]
# Tour found with TD learning: [0, 1, 4, 2, 3, 5]
# TD learning Tour Cost: 15.615210636907408
# Tour found with OR Tools: [0, 1, 4, 5, 3, 2]
# OR Tools Tour Cost: 14.9456
# Accuracy: 95.5196804617586
#
#
#
# Instance 69:
# locations:  [(0.43426489996676754, 1.1541632095784338), (4.215176294895895, 1.7928690483379317), (6.028395656821164, 0.6218145957652865), (3.223210748897772, 0.16338720598791268), (5.283598196887803, 9.305707981056152), (2.672477415062912, 6.622902679105746), (6.255121403707276, 7.237428842949379)]
# Tour found with TD learning: [0, 3, 1, 2, 6, 4, 5]
# TD learning Tour Cost: 25.5832167171408
# Tour found with OR Tools: [0, 3, 1, 2, 6, 4, 5]
# OR Tools Tour Cost: 25.5829
# Accuracy: 99.99876199672124
#
#
#
# Instance 70:
# locations:  [(3.6921436739391833, 3.5329813832200685), (1.6544824496925215, 2.1989627119503217), (6.1669555869939865, 8.75038558586721), (1.2351100419264682, 5.853237242563853), (1.894950301333247, 6.289950494332616), (3.7364504940811716, 4.009397879213166), (0.7732846864299014, 9.703103571430807), (1.411398491275735, 5.093050052766868)]
# Tour found with TD learning: [0, 5, 7, 3, 4, 6, 2, 1]
# TD learning Tour Cost: 24.075786554011756
# Tour found with OR Tools: [0, 5, 2, 6, 4, 3, 7, 1]
# OR Tools Tour Cost: 21.787
# Accuracy: 89.49471449023841
#
#
#
# Instance 71:
# locations:  [(9.293292491202362, 3.4824412154023356), (3.805812922348167, 3.7680179053626803), (1.186923731454823, 9.8828975216343), (4.157201152190418, 8.169032982614826), (0.12847226948330404, 9.155334878608498), (9.86716057573528, 6.425524407717304), (7.867631477782165, 4.208331001040469), (0.5875045180701233, 2.7336125606096715)]
# Tour found with TD learning: [0, 6, 5, 3, 2, 4, 7, 1]
# TD learning Tour Cost: 30.58281123585548
# Tour found with OR Tools: [0, 6, 1, 7, 4, 2, 3, 5]
# OR Tools Tour Cost: 29.1861
# Accuracy: 95.21446429685541
#
#
#
# Instance 72:
# locations:  [(2.300612687869026, 9.614604592239907), (8.22199877298125, 1.0427166488954653), (1.042124122375463, 4.510340136535737), (5.253197540644484, 4.151695737271019), (8.277985921085032, 8.344060887050102), (5.671553490671942, 6.754047622277062), (2.9020964543709225, 4.063739454814516), (7.377190363651947, 4.7540273476680746), (9.719402363276384, 9.07432338020118)]
# Tour found with TD learning: [0, 5, 7, 3, 6, 2, 1, 4, 8]
# TD learning Tour Cost: 37.8522086970904
# Tour found with OR Tools: [0, 5, 4, 8, 7, 1, 3, 6, 2]
# OR Tools Tour Cost: 31.6317
# Accuracy: 80.33457355409162
#
#
#
# Instance 73:
# locations:  [(0.5797734439805557, 6.3768109959454575), (0.6074994913399423, 0.7507623944543496), (2.295142808508527, 5.703262287756528), (4.4121010026637775, 3.9297675108816597), (8.058085893858335, 5.208300353832528)]
# Tour found with TD learning: [0, 2, 3, 4, 1]
# TD learning Tour Cost: 22.776523923032826
# Tour found with OR Tools: [0, 2, 4, 3, 1]
# OR Tools Tour Cost: 22.0745
# Accuracy: 96.81975164541518
#
#
#
# Instance 74:
# locations:  [(5.557795855461297, 4.924992925109492), (5.193644495057344, 8.882443104078682), (0.5695635060315141, 9.418941247408062), (0.6366911442387102, 9.03285060109808), (1.7021257461441974, 4.422240659922725), (5.754534733314458, 6.406921557446795)]
# Tour found with TD learning: [0, 5, 1, 3, 2, 4]
# TD learning Tour Cost: 17.99627379737851
# Tour found with OR Tools: [0, 5, 1, 2, 3, 4]
# OR Tools Tour Cost: 17.7003
# Accuracy: 98.32785999458477
#
#
#
# Instance 75:
# locations:  [(2.0287448240397787, 5.0077360620476), (5.660846462987202, 8.41104571881737), (4.428504835168465, 6.925695314991064), (7.834599008274642, 9.737164685042744), (6.907442618683135, 5.770140019992267)]
# Tour found with TD learning: [0, 2, 1, 3, 4]
# TD learning Tour Cost: 16.56021442834325
# Tour found with OR Tools: [0, 2, 1, 3, 4]
# OR Tools Tour Cost: 16.5601
# Accuracy: 99.9993090117617
#
#
#
# Instance 76:
# locations:  [(4.110946534898524, 4.587946271752128), (6.693193581146936, 7.085021725934052), (4.076784726336239, 8.528646818219661), (7.542518006773371, 0.5330450287394894), (9.818012358902301, 1.5000193304170018), (8.37806048194613, 1.3088915992470007), (9.617814082313075, 9.488527835331496)]
# Tour found with TD learning: [0, 1, 2, 6, 4, 5, 3]
# TD learning Tour Cost: 28.09979196931726
# Tour found with OR Tools: [0, 2, 1, 6, 4, 5, 3]
# OR Tools Tour Cost: 26.6102
# Accuracy: 94.40217672427393
#
#
#
# Instance 77:
# locations:  [(8.818460991829213, 5.118963017977528), (2.7386437142431355, 3.1326749860688574), (5.741480409488473, 0.5954592165674477), (4.315557551354779, 5.682670219952158), (9.524456542711638, 9.136492017169134)]
# Tour found with TD learning: [0, 4, 3, 1, 2]
# TD learning Tour Cost: 22.72924103858783
# Tour found with OR Tools: [0, 4, 3, 1, 2]
# OR Tools Tour Cost: 22.729
# Accuracy: 99.99893951081073
#
#
#
# Instance 78:
# locations:  [(8.898423726461552, 8.895382716520494), (1.5580245349431499, 1.8198949195301317), (9.18094501201365, 6.498646703836254), (5.364686675899594, 5.269757736451746), (3.6570140350851554, 7.20077613969171), (5.295474801192701, 4.2103260523206085), (5.783006161938022, 6.842775730641724), (7.143137244643418, 0.27026970608201917)]
# Tour found with TD learning: [0, 2, 6, 3, 5, 4, 1, 7]
# TD learning Tour Cost: 32.30171410231181
# Tour found with OR Tools: [0, 2, 7, 1, 5, 3, 4, 6]
# OR Tools Tour Cost: 28.7251
# Accuracy: 87.54881931721104
#
#
#
# Instance 79:
# locations:  [(7.768899927826381, 9.283695411393373), (3.380655002810631, 6.679165276726453), (1.7773920636322749, 0.5981712356603375), (2.5618605362680036, 7.218700616811303), (6.697449236379374, 7.565030584664408), (8.142921761632184, 6.4735423166928445)]
# Tour found with TD learning: [0, 4, 5, 1, 3, 2]
# TD learning Tour Cost: 26.80230545055287
# Tour found with OR Tools: [0, 5, 2, 3, 1, 4]
# OR Tools Tour Cost: 24.6029
# Accuracy: 91.06038129426666
#
#
#
# Instance 80:
# locations:  [(4.88031867577785, 0.8246855855548241), (2.538522596073589, 6.52278589390732), (9.31346246503875, 5.277338462953205), (4.666924259649079, 6.370080141712445), (0.6246238287415096, 8.44388644780081)]
# Tour found with TD learning: [0, 3, 1, 4, 2]
# TD learning Tour Cost: 25.926214156345743
# Tour found with OR Tools: [0, 1, 4, 3, 2]
# OR Tools Tour Cost: 24.4719
# Accuracy: 94.05720783287876
#
#
#
# Instance 81:
# locations:  [(3.728637735480822, 4.193262858757593), (2.4072217362845363, 9.25723124310588), (6.92555172084278, 0.19095758989198353), (4.084740181629475, 0.05622784521570723), (0.5835693200825653, 3.966387900131245), (3.0244097056602905, 2.7316074856199277), (6.385406281802989, 3.4219012568743223), (7.9656363548601306, 6.416456326226413)]
# Tour found with TD learning: [0, 5, 4, 3, 2, 6, 7, 1]
# TD learning Tour Cost: 30.58795308275735
# Tour found with OR Tools: [0, 4, 1, 7, 6, 2, 3, 5]
# OR Tools Tour Cost: 28.9975
# Accuracy: 94.51520619792275
#
#
#
# Instance 82:
# locations:  [(0.6031379243810153, 1.0502222965711772), (7.946598884727745, 9.628866271248162), (1.6957601856002857, 8.0198005656861), (0.0953634542981141, 8.23643378629178), (7.319677392397214, 5.816904633523544), (7.013546076768695, 2.769108640160125), (4.396561693340581, 0.9747694962818987), (8.694033417718739, 3.7889416172795096), (3.228671507994081, 8.886151292413736)]
# Tour found with TD learning: [0, 6, 5, 7, 4, 1, 8, 2, 3]
# TD learning Tour Cost: 30.601861285870825
# Tour found with OR Tools: [0, 6, 5, 7, 4, 1, 8, 2, 3]
# OR Tools Tour Cost: 30.6013
# Accuracy: 99.99816581037136
#
#
#
# Instance 83:
# locations:  [(9.948475670266738, 7.346792740309239), (7.125725458918425, 4.945305915369625), (9.819732126025176, 8.526886130581556), (2.8003436726674327, 2.2703045749252695), (4.509110127680987, 5.2068978634496865), (9.27762060754146, 5.292299454326472)]
# Tour found with TD learning: [0, 2, 5, 1, 4, 3]
# TD learning Tour Cost: 21.441069595262576
# Tour found with OR Tools: [0, 2, 4, 3, 1, 5]
# OR Tools Tour Cost: 20.2739
# Accuracy: 94.24299421787336
#
#
#
# Instance 84:
# locations:  [(7.678786598154003, 1.0044025976412674), (3.1167723749809726, 5.831498995542987), (5.817004905972979, 8.298149195348735), (9.075928684100976, 5.4283080271100115), (8.604769530375107, 5.494571870699313), (6.3426845769104165, 2.827300103834247), (8.705824827755334, 5.1325106032838805), (5.50334319968613, 5.0391721196539265)]
# Tour found with TD learning: [0, 5, 7, 1, 2, 4, 6, 3]
# TD learning Tour Cost: 20.24047345202625
# Tour found with OR Tools: [0, 5, 7, 1, 2, 4, 3, 6]
# OR Tools Tour Cost: 19.9545
# Accuracy: 98.56687237452077
#
#
#
# Instance 85:
# locations:  [(2.4868210251620217, 4.22568545019244), (9.270137267757757, 8.75366431444074), (5.914952720017892, 1.3036423948403442), (8.481948465320507, 1.9257286275124996), (4.097321004890566, 2.8712439969444525), (5.43806307278044, 9.30330642923524)]
# Tour found with TD learning: [0, 4, 2, 3, 1, 5]
# TD learning Tour Cost: 23.76343823842906
# Tour found with OR Tools: [0, 4, 2, 3, 1, 5]
# OR Tools Tour Cost: 23.763
# Accuracy: 99.99815579502143
#
#
#
# Instance 86:
# locations:  [(3.6825600485755072, 2.0057184013570186), (8.042778714675281, 9.47164784723071), (9.956646023753722, 3.9495969294155953), (1.6220344843548506, 1.6860075735718993), (1.7049100411212692, 6.952563095864005), (4.5368086517929305, 5.747978052706974), (4.734945561486272, 6.354934713572662), (7.879776603452013, 9.119967828989918), (1.2105861848648336, 5.018763586913776)]
# Tour found with TD learning: [0, 3, 8, 4, 5, 6, 7, 1, 2]
# TD learning Tour Cost: 28.14291544791294
# Tour found with OR Tools: [0, 3, 8, 4, 5, 6, 7, 1, 2]
# OR Tools Tour Cost: 28.1425
# Accuracy: 99.99852377040796
#
#
#
# Instance 87:
# locations:  [(6.510680041349972, 6.1497466351913825), (7.363956543741949, 2.6106127629743914), (0.617092395916985, 9.416500071245142), (2.2601178311883086, 3.4915361649164787), (5.552339832448631, 4.5534005725517135), (4.151755568551831, 0.8529640210121514), (1.073667377130909, 6.296531848164266), (6.173485332750559, 2.4889623232605906)]
# Tour found with TD learning: [0, 4, 7, 1, 5, 3, 6, 2]
# TD learning Tour Cost: 25.059870301489653
# Tour found with OR Tools: [0, 4, 1, 7, 5, 3, 6, 2]
# OR Tools Tour Cost: 24.499
# Accuracy: 97.71064002004304
#
#
#
# Instance 88:
# locations:  [(8.28681711894964, 6.484295000168777), (9.87410105803851, 1.896516128524296), (0.7771961186690513, 3.100649075428621), (1.605152427471489, 3.321385334711419), (4.547680766015658, 4.334683866547698), (0.916895850847026, 7.374411688469741), (9.10624327787682, 4.652360981405723)]
# Tour found with TD learning: [0, 6, 1, 4, 3, 2, 5]
# TD learning Tour Cost: 26.394117342261733
# Tour found with OR Tools: [0, 6, 1, 4, 3, 2, 5]
# OR Tools Tour Cost: 26.3938
# Accuracy: 99.9987976636114
#
#
#
# Instance 89:
# locations:  [(6.102068539936822, 8.825832980759799), (0.009580668957025473, 0.6193637653172424), (0.9303503421797266, 0.6411927927919359), (3.6298200107389125, 2.5236815780750064), (2.5065362164124725, 5.799401277057671), (2.639135077389362, 0.562897568014542), (4.707402507407831, 8.338614733342228)]
# Tour found with TD learning: [0, 6, 4, 3, 5, 2, 1]
# TD learning Tour Cost: 23.34979402387824
# Tour found with OR Tools: [0, 6, 4, 1, 2, 5, 3]
# OR Tools Tour Cost: 22.1859
# Accuracy: 94.75390214560491
#
#
#
# Instance 90:
# locations:  [(8.703802538599202, 2.6918965285353416), (6.600576808351314, 1.992785105760423), (4.89007208551632, 4.668739460729228), (2.672933703278285, 6.494927632176234), (7.773898745513942, 6.258392524747709), (7.125261180894448, 3.1630168909418233), (9.54514730650692, 4.125498294813669)]
# Tour found with TD learning: [0, 5, 1, 2, 3, 4, 6]
# TD learning Tour Cost: 18.519310315640713
# Tour found with OR Tools: [0, 5, 1, 2, 3, 4, 6]
# OR Tools Tour Cost: 18.5189
# Accuracy: 99.99778434118272
#
#
#
# Instance 91:
# locations:  [(7.045015862958419, 7.769970225466924), (3.980120109037771, 2.288509471165956), (6.105721967293071, 0.8405797956563033), (9.232359597825486, 8.024804864911845), (9.32457550840424, 0.044626316888537465), (1.8783805811433663, 8.962465071911472), (0.2484378334183579, 0.8899737449446354), (2.8319077227961142, 9.177645135424639)]
# Tour found with TD learning: [0, 3, 7, 5, 1, 2, 4, 6]
# TD learning Tour Cost: 41.354267084216794
# Tour found with OR Tools: [0, 3, 4, 2, 1, 6, 5, 7]
# OR Tools Tour Cost: 33.7105
# Accuracy: 77.32526339206838
#
#
#
# Instance 92:
# locations:  [(4.260612847444353, 9.112809559919432), (1.9534074951218983, 5.444450257160332), (1.9926658652913998, 2.3328842297021035), (8.386166641308492, 8.891227453101253), (0.6752418639325863, 3.453883567815421)]
# Tour found with TD learning: [0, 3, 1, 4, 2]
# TD learning Tour Cost: 22.674094930492107
# Tour found with OR Tools: [0, 3, 2, 4, 1]
# OR Tools Tour Cost: 21.7193
# Accuracy: 95.60393322762654
#
#
#
# Instance 93:
# locations:  [(8.352272791766701, 9.64945275752216), (4.87718535164661, 2.8426972599423186), (9.320246840100443, 9.964034449307327), (4.984024225282894, 4.368188730596345), (4.3566680383386815, 2.624128917746363), (0.12965995535831998, 8.13218720121964), (1.2719889524191341, 4.931563867286059), (1.8816131611848264, 4.947401826050242), (3.0096806323580227, 7.647778848091253)]
# Tour found with TD learning: [0, 2, 8, 5, 6, 7, 3, 1, 4]
# TD learning Tour Cost: 28.000575057141525
# Tour found with OR Tools: [0, 2, 3, 1, 4, 7, 6, 5, 8]
# OR Tools Tour Cost: 26.219
# Accuracy: 93.20502285693
#
#
#
# Instance 94:
# locations:  [(7.457549709209843, 1.525587266390358), (2.2751235750515972, 0.4054002177529059), (6.988249421273825, 9.981229037084226), (8.919880463094051, 7.778063336628504), (9.783706737121154, 5.68471373705374), (5.770266115677305, 4.236924990190225), (4.108839749471597, 7.209604327375976), (9.872680814555535, 5.05106742703317)]
# Tour found with TD learning: [0, 5, 6, 2, 3, 4, 7, 1]
# TD learning Tour Cost: 30.637476133561655
# Tour found with OR Tools: [0, 7, 4, 3, 2, 6, 5, 1]
# OR Tools Tour Cost: 27.9978
# Accuracy: 90.57184445362974
#
#
#
# Instance 95:
# locations:  [(2.781602215988015, 6.383049500838079), (3.274778804498003, 1.3882811758356706), (6.7251837343631005, 8.3078426710218), (5.737233966124848, 1.0446463017329033), (5.3444894624219135, 0.6039377846417582), (1.1359217886530204, 8.605702763321656)]
# Tour found with TD learning: [0, 5, 2, 3, 4, 1]
# TD learning Tour Cost: 23.515573571373835
# Tour found with OR Tools: [0, 5, 2, 3, 4, 1]
# OR Tools Tour Cost: 23.5152
# Accuracy: 99.99841136212393
#
#
#
# Instance 96:
# locations:  [(0.4297552807640215, 4.916995645250404), (7.854240030958363, 4.793911983249969), (1.0959134536466053, 2.8293736698853813), (6.947187003616322, 9.070760925848681), (0.5335425647169456, 6.4326813874136874), (9.477747513300468, 3.8860925537542714), (6.478391929544777, 7.054506873142104)]
# Tour found with TD learning: [0, 4, 2, 6, 3, 1, 5]
# TD learning Tour Cost: 29.417513101253313
# Tour found with OR Tools: [0, 4, 3, 6, 1, 5, 2]
# OR Tools Tour Cost: 25.6699
# Accuracy: 85.40074912152632
#
#
#
# Instance 97:
# locations:  [(3.9892883717030103, 3.0846402267294226), (3.9789736255355566, 8.31329884651961), (4.557131385987109, 6.04348273668616), (8.841794993918846, 1.3025316765812434), (0.7418813687921755, 7.219498184558432), (6.164168461861608, 8.377139737563061), (4.508348428395755, 4.7522645674158355), (2.514290881587203, 2.22574453435477), (8.058512026823582, 3.9630087757087384)]
# Tour found with TD learning: [0, 7, 6, 2, 1, 5, 8, 3, 4]
# TD learning Tour Cost: 33.61140324290776
# Tour found with OR Tools: [0, 7, 4, 1, 5, 2, 6, 8, 3]
# OR Tools Tour Cost: 28.3136
# Accuracy: 81.28883913416958
#
#
#
# Instance 98:
# locations:  [(6.151585245685444, 6.341549499581146), (5.65536352638569, 0.998670478865884), (1.2630166833406753, 7.728521265386843), (1.9689632304998195, 8.060902733317096), (4.562221430729587, 1.5107117520324176)]
# Tour found with TD learning: [0, 3, 2, 4, 1]
# TD learning Tour Cost: 18.914385145370005
# Tour found with OR Tools: [0, 3, 2, 4, 1]
# OR Tools Tour Cost: 18.9141
# Accuracy: 99.99849241904187
#
#
#
# Instance 99:
# locations:  [(0.20534860257463206, 7.546121529489041), (8.165784240052416, 1.630768693873309), (2.227338213710862, 7.856029566265569), (0.8611434194826717, 9.246546736086227), (2.574688041261801, 0.21193289587149167)]
# Tour found with TD learning: [0, 3, 2, 4, 1]
# TD learning Tour Cost: 27.109823989798308
# Tour found with OR Tools: [0, 3, 2, 1, 4]
# OR Tools Tour Cost: 25.8509
# Accuracy: 95.13005740690534
#
#
#
# Instance 100:
# locations:  [(1.856806668687202, 1.1702619582472962), (8.995833584020872, 3.6233156588405535e-05), (4.012022931455031, 9.840520429802726), (5.804881058409165, 2.68595229155683), (8.185775148193015, 6.308154611042615), (2.355535904134618, 0.586005908194136), (8.220583040795757, 5.450657266585033), (5.171315795326384, 7.603670414160039)]
# Tour found with TD learning: [0, 5, 3, 6, 4, 7, 2, 1]
# TD learning Tour Cost: 33.40141024202235
# Tour found with OR Tools: [0, 5, 3, 1, 6, 4, 7, 2]
# OR Tools Tour Cost: 30.0752
# Accuracy: 88.94035536913353
#
# Average Percent Accuracy: 92.51882006466559
