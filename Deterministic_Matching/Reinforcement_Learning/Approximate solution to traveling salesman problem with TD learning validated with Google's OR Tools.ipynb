# %%
import numpy as np
import math
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

global scaling_factor; scaling_factor = 10000 #scaling_factor for OR tools to deal with it only being able to handle integers 

def compute_euclidean_distance_matrix(locations):
    global scaling_factor; 
    """Creates callback to return distance between points."""
    distances = {}
    for from_counter, from_node in enumerate(locations):
        distances[from_counter] = {}
        for to_counter, to_node in enumerate(locations):
            if from_counter == to_counter:
                distances[from_counter][to_counter] = 0
            else:
                # Euclidean distance
                distances[from_counter][to_counter] = (scaling_factor*(
                    math.hypot((from_node[0] - to_node[0]),
                               (from_node[1] - to_node[1])))) 
    return distances


def print_solution(manager, routing, solution, print_sol = False):
    """Prints solution on console."""
    global scaling_factor
    
    cost = solution.ObjectiveValue()/scaling_factor
    
    #print('Objective: {}'.format(cost))
    index = routing.Start(0)
    plan_output = 'Route:\n'
    route_distance = 0
    array_best_path = []
    
    while not routing.IsEnd(index):
        plan_output += ' {} ->'.format(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        array_best_path.append(previous_index)
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    
    if print_sol: 
        plan_output += ' {}\n'.format(manager.IndexToNode(index))
        print(plan_output)
        plan_output += 'Objective: {}m\n'.format(route_distance)
        #print('Best path array: ', array_best_path)
    
    return array_best_path, cost

def solve_tsp_with_ortools(locations):
    global scaling_factor; 
    """Entry point of the program."""
    # Instantiate the data dictionary. 
    data = {'locations': locations, 'num_vehicles': 1, 'depot': 0}

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['locations']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)

    distance_matrix = compute_euclidean_distance_matrix(data['locations'])

    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return distance_matrix[from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        array_best_path, cost = print_solution(manager, routing, solution)

        return array_best_path, cost

#Solve with TD learning

def euclidean_dist(x,y):
    return ((locations[x][0]-locations[y][0])**2+ (locations[x][1]-locations[y][1])**2)**0.5

def path_cost(path):
    cost = 0 
    for i in range(1, len(path)): 
        cost+=euclidean_dist(path[i], path[i-1])
    cost+=euclidean_dist(path[-1], path[0])
    return cost 

def solve_tsp_with_td_learning(locations): 
    
    #define training parameters
    epsilon = 1 #the percentage of time when we should take a random action 
    discount_factor = 1 #discount factor for future rewards
    learning_rate = 0.1 #the rate at which the AI agent should learn
      
    q_values = np.zeros((len(locations), len(locations)))
 
    depot = 0 
    
    n_training_episodes = 1000 
    
    for episode in range(n_training_episodes): 
        current_state = depot  
        possible_next_states = [i for i in range(1, len(locations))] #next state to visit; depot must be 0 for this to work  
        
        while possible_next_states:  
            
            if np.random.random() < epsilon:
                next_state = np.random.choice(possible_next_states)  #pick random action with probability epsilon  
            else:  
                next_state = possible_next_states[np.argmax(q_values[current_state, possible_next_states])] 
                 
            possible_next_states.remove(next_state) 
                 
            reward = -euclidean_dist(current_state, next_state) #aim is to maximize reward 
               
            q_values[current_state, next_state] += learning_rate*(reward + discount_factor * max(q_values[next_state]) - q_values[current_state, next_state])
            #max(q_values[action, possible_next_states]) instead max(q_values[action]) generates unstable results 
            
            current_state = next_state
            
        q_values[current_state, depot] += learning_rate*(reward -  q_values[current_state, depot]) #terminal state update 
             
        epsilon = 1-episode/n_training_episodes #gradual decay 
        
    #print('q_values: ', q_values)
    
    optimal_path = [depot]
    current_state = depot 
    
    possible_next_states = [i for i in range(1, len(locations))]
    
    while possible_next_states:  
        next_loc = possible_next_states[np.argmax(q_values[current_state, possible_next_states])] 
        current_state = next_loc 
        possible_next_states.remove(next_loc) 
        optimal_path.append(next_loc)
      
    cost = path_cost(optimal_path)
    
    #print('optimal_path with TD learning: ', optimal_path); print('cost with TD learning: ', cost) 
     
    return optimal_path, cost  
  
if __name__ == '__main__':
    
    # Set the print options to automatically round to 4 decimal places
    np.set_printoptions(precision=4, suppress=True)
     
    # Generate a range of instances and compare the approximate solution with optimal solution
    num_instances = 100 
    total_accuracy = 0

    for i in range(num_instances):
        # Generate a random instance with random locations
        num_cities = np.random.randint(5, 10)
        locations = [(np.random.uniform(0, 10), np.random.uniform(0, 10)) for _ in range(num_cities)]
        
        #locations = [(8.676089077829092, 9.607186311344309), (3.9082981175655043, 0.9551773757562187), (6.7593875421776275, 0.655368856076185), (1.363960984786834, 6.393370716253527), (0.4293271060519832, 6.039203102672753), (8.444047383539294, 2.384973604150419), (0.7407410477601184, 6.652093387384986), (1.9356376041625356, 1.9449765216843296), (2.8543396796479636, 2.4861992695755344)]
        #num_cities = len(locations)
        
        print(f"\n\nInstance {i+1}:")
        print('locations: ', locations)
        distance_matrix = np.zeros((num_cities, num_cities))
        
        for j in range(num_cities):
            for k in range(num_cities):
                distance_matrix[j, k] = np.linalg.norm(np.array(locations[j]) - np.array(locations[k]))

        # Solve TSP using OR-Tools to get the optimal tour cost
        or_tools_path, or_tools_path_cost = solve_tsp_with_ortools(distance_matrix)
          
        td_learning_path, td_learning_path_cost = solve_tsp_with_td_learning(locations)

        # Calculate the accuracy of the approximate solution 
        if td_learning_path_cost > or_tools_path_cost: 
            accuracy = (1 - (abs(td_learning_path_cost - or_tools_path_cost) / or_tools_path_cost)) * 100 #this is a percentage 
        else:
            accuracy = 100 #this is a percentage 
            
        total_accuracy += accuracy

        # Print the results for each instance 
        print("Tour found with TD learning:", td_learning_path)
        print("TD learning Tour Cost:", td_learning_path_cost)
        print("Tour found with OR Tools:", or_tools_path)
        print("OR Tools Tour Cost:", or_tools_path_cost)
        print("Accuracy:", accuracy)
        print()

    # Print the average accuracy across all instances
    average_accuracy = total_accuracy / num_instances
    print("Average Percent Accuracy:", average_accuracy)
# Out:
# Instance 1:
# locations:  [(3.8215314385337362, 1.0766778110517705), (0.7701553957796203, 9.545892538168175), (5.514352270977129, 6.33585182206078), (7.771669024951793, 9.712691864990418), (7.93691037194403, 4.804549144792726), (6.024993530441457, 2.6002152680759547), (8.314804907094958, 4.088425777157383), (6.869438851393035, 2.6431723622339156), (6.4691592436583765, 1.8815965595508288)]
# Tour found with TD learning: [0, 5, 8, 7, 6, 4, 2, 3, 1]
# TD learning Tour Cost: 30.171167382759638
# Tour found with OR Tools: [0, 5, 2, 1, 3, 4, 6, 7, 8]
# OR Tools Tour Cost: 31.0705
# Accuracy: 100
#
#
#
# Instance 2:
# locations:  [(0.963685904890601, 4.632194307684102), (4.191754859700589, 3.1113301248250758), (8.057793371084635, 8.410527042309836), (0.21960105545430597, 8.084765525091091), (3.236464169788097, 8.41258673777704), (1.8989709290020707, 1.396864290334917), (6.439972849832669, 4.268005676427497)]
# Tour found with TD learning: [0, 5, 1, 6, 2, 4, 3]
# TD learning Tour Cost: 24.594052542460872
# Tour found with OR Tools: [0, 5, 1, 6, 2, 4, 3]
# OR Tools Tour Cost: 23.8868
# Accuracy: 97.0391490594769
#
#
#
# Instance 3:
# locations:  [(8.519495303381936, 5.497252908561105), (7.203187901394087, 7.069192933695617), (1.5092826056821917, 6.055599872070417), (5.08975619640508, 9.21004564562413), (8.257912314627497, 3.168830528284068)]
# Tour found with TD learning: [0, 1, 3, 2, 4]
# TD learning Tour Cost: 19.51359970397742
# Tour found with OR Tools: [0, 1, 3, 2, 4]
# OR Tools Tour Cost: 18.6356
# Accuracy: 95.28858902328115
#
#
#
# Instance 4:
# locations:  [(4.595559206569146, 8.795133764171192), (9.35531597912423, 5.652766373375401), (1.8108569146558262, 4.882845438278858), (8.424688236676673, 9.157384268285082), (3.196957632720748, 4.002309504419252), (0.9904426331405736, 6.777204637997326), (4.891433625916939, 6.606195242609242), (6.818925193650687, 1.6170118448594428)]
# Tour found with TD learning: [0, 6, 4, 2, 5, 7, 1, 3]
# TD learning Tour Cost: 29.04548273788013
# Tour found with OR Tools: [0, 6, 3, 1, 7, 4, 2, 5]
# OR Tools Tour Cost: 23.8029
# Accuracy: 77.975025152901
#
#
#
# Instance 5:
# locations:  [(9.214883744749171, 4.8968286949034745), (9.100863326692956, 9.378962383499903), (5.60109071354929, 5.113858580198017), (1.8266228607710533, 8.638482138493245), (7.3132673594403865, 0.05456172020457006), (2.7725334455559025, 1.1244436325617435), (1.6396773723284486, 2.160647470401671)]
# Tour found with TD learning: [0, 2, 5, 6, 4, 1, 3]
# TD learning Tour Cost: 41.185603031928835
# Tour found with OR Tools: [0, 2, 4, 5, 6, 3, 1]
# OR Tools Tour Cost: 28.73
# Accuracy: 56.64600406568453
#
#
#
# Instance 6:
# locations:  [(0.4584955103076016, 2.987885636617056), (7.8608113288432415, 6.3304205737710895), (8.798501136510282, 2.5460231715136317), (6.790883906779193, 6.55573909855182), (4.384937612749752, 9.15008906389268), (4.908246640416146, 6.846357473988778), (9.857956591459399, 2.76160544278369)]
# Tour found with TD learning: [0, 5, 3, 1, 2, 6, 4]
# TD learning Tour Cost: 29.58711197253335
# Tour found with OR Tools: [0, 5, 3, 1, 6, 2, 4]
# OR Tools Tour Cost: 26.2571
# Accuracy: 87.31767037283878
#
#
#
# Instance 7:
# locations:  [(3.8239994601046767, 6.200423753260999), (0.06468431020718368, 9.823480479691627), (5.014569676512201, 1.7299238532732952), (8.872594486462317, 9.687381460353066), (6.65342865495365, 1.4635319823548165), (4.602140709465678, 0.5495081569018567), (8.560136727428935, 8.627100444020021), (1.560503098089464, 7.2081305473953226)]
# Tour found with TD learning: [0, 7, 1, 6, 3, 4, 2, 5]
# TD learning Tour Cost: 32.30821762471964
# Tour found with OR Tools: [0, 7, 1, 6, 3, 5, 4, 2]
# OR Tools Tour Cost: 26.5186
# Accuracy: 78.16771011773005
#
#
#
# Instance 8:
# locations:  [(1.6521003391035272, 3.035685410521051), (6.5211076979046245, 5.3656614596582894), (7.742753596993239, 3.955745075901663), (2.535893314746377, 3.665208604394472), (6.349838969274924, 9.547995977346204), (6.380657896121016, 5.353213794083619)]
# Tour found with TD learning: [0, 3, 5, 1, 2, 4]
# TD learning Tour Cost: 21.083616435596745
# Tour found with OR Tools: [0, 3, 5, 1, 2, 4]
# OR Tools Tour Cost: 20.7497
# Accuracy: 98.39074089940219
#
#
#
# Instance 9:
# locations:  [(7.231302931482374, 3.640599136924184), (7.985416865103271, 4.13621977642033), (5.877981690190969, 1.508492261684371), (6.305072144899068, 1.11805830663395), (0.478260055139198, 2.2028960801710493), (8.128704414154855, 0.7889494014319298), (8.179491627574434, 5.904973442295813), (5.322443411030932, 1.0979681365969296), (2.547135247151442, 5.457998383837916)]
# Tour found with TD learning: [0, 1, 6, 2, 3, 7, 5, 8, 4]
# TD learning Tour Cost: 30.067211677934527
# Tour found with OR Tools: [0, 1, 6, 5, 8, 4, 7, 3, 2]
# OR Tools Tour Cost: 20.9244
# Accuracy: 56.30550133846357
#
#
#
# Instance 10:
# locations:  [(7.553718703374848, 0.37040161297836827), (4.536136501481446, 8.183568848859853), (4.960826664617234, 5.985443369465528), (1.4267122968882873, 7.221429380607779), (9.069107984846811, 2.8093500725476153), (9.306714084719959, 3.8772582001240963), (0.37282576184654026, 5.989723668296268)]
# Tour found with TD learning: [0, 4, 5, 2, 1, 3, 6]
# TD learning Tour Cost: 25.028566510979797
# Tour found with OR Tools: [0, 4, 5, 6, 3, 1, 2]
# OR Tools Tour Cost: 26.5097
# Accuracy: 100
#
#
#
# Instance 11:
# locations:  [(8.924429875924714, 8.731015901387527), (9.349345489365117, 4.060213177367561), (4.0708312311478725, 3.0498501342240116), (9.535554501906857, 5.14521428487247), (7.265991544929998, 7.42591501395606), (9.240769994874237, 1.806544992989465), (2.5339874212294333, 0.4109038016569355), (5.946895695988218, 1.7009307700314524)]
# Tour found with TD learning: [0, 4, 3, 1, 5, 7, 2, 6]
# TD learning Tour Cost: 27.8361794558094
# Tour found with OR Tools: [0, 4, 2, 6, 7, 5, 1, 3]
# OR Tools Tour Cost: 28.0215
# Accuracy: 100
#
#
#
# Instance 12:
# locations:  [(0.9204963867377636, 6.962564195792968), (0.5681174421702384, 3.335094014226395), (3.1467360782368026, 5.181395949700027), (5.862096239400874, 4.1985752627837005), (4.282167042307741, 2.2205157591414393), (1.5755419454241504, 5.123805730751866), (9.493237381067493, 1.8120685457643304), (4.78094755057708, 7.867508360967209)]
# Tour found with TD learning: [0, 5, 2, 3, 4, 1, 7, 6]
# TD learning Tour Cost: 36.68308534692095
# Tour found with OR Tools: [0, 2, 7, 6, 3, 4, 1, 5]
# OR Tools Tour Cost: 29.5989
# Accuracy: 76.06605195827903
#
#
#
# Instance 13:
# locations:  [(8.365786977170123, 6.691528912415116), (0.17942228405142258, 1.4831679297606104), (5.373321780385, 7.574373660386481), (6.461401492803995, 1.8467083580826815), (4.172012765822894, 7.338352026911564), (1.1683559869451121, 1.1385273471177881), (9.708856640516021, 3.1073138422933866), (7.723772233970982, 2.012293853175792)]
# Tour found with TD learning: [0, 2, 4, 3, 7, 6, 5, 1]
# TD learning Tour Cost: 33.348773945909855
# Tour found with OR Tools: [0, 6, 7, 5, 1, 3, 4, 2]
# OR Tools Tour Cost: 29.1561
# Accuracy: 85.61990819790762
#
#
#
# Instance 14:
# locations:  [(0.5828978659770478, 9.002842368965334), (2.0608408209057982, 4.101199703492186), (4.335815265020258, 6.4124021909587885), (2.95977328141852, 3.636136862208288), (6.435796958984538, 6.849215240659815), (1.0371137133491182, 1.6924892042900896), (0.65153539129018, 5.662237086862774)]
# Tour found with TD learning: [0, 6, 1, 3, 5, 2, 4]
# TD learning Tour Cost: 23.3303045472834
# Tour found with OR Tools: [0, 6, 1, 3, 5, 4, 2]
# OR Tools Tour Cost: 20.9357
# Accuracy: 88.56209944122527
#
#
#
# Instance 15:
# locations:  [(9.507330412753763, 7.783237912872018), (3.8946243670933156, 0.8351486645160444), (0.6340095066767393, 4.225719551216846), (0.6734137160057352, 5.125735078490694), (1.831493372279579, 4.182539498262151)]
# Tour found with TD learning: [0, 4, 2, 3, 1]
# TD learning Tour Cost: 24.87462620771577
# Tour found with OR Tools: [0, 3, 2, 4, 1]
# OR Tools Tour Cost: 28.5497
# Accuracy: 100
#
#
#
# Instance 16:
# locations:  [(3.4051877759964078, 7.480505681722564), (2.3412151107404036, 6.612732630151638), (2.8291883312282184, 4.252658873225464), (6.78957901220671, 9.111282697453541), (3.3122534476197285, 9.417817054221853), (1.2399444169781804, 3.6950547051575757), (8.57837606386462, 3.3505498496363173), (6.996654409386619, 0.18987467810330783)]
# Tour found with TD learning: [0, 1, 2, 5, 4, 3, 6, 7]
# TD learning Tour Cost: 32.73808748529338
# Tour found with OR Tools: [0, 1, 2, 5, 7, 6, 3, 4]
# OR Tools Tour Cost: 22.9427
# Accuracy: 57.304992501783225
#
#
#
# Instance 17:
# locations:  [(3.893229503711436, 1.1972792779649022), (1.3028211688695945, 9.57208770345294), (9.240606288400684, 4.386906949873151), (0.26725461695715214, 3.9986711771502526), (2.8106157665103004, 1.8178061657592048), (0.27753340263452886, 2.088360743253789), (1.7075384426950302, 6.120135298669727), (5.5978650508440175, 0.1459322762346471)]
# Tour found with TD learning: [0, 4, 5, 3, 6, 1, 2, 7]
# TD learning Tour Cost: 28.82015160735585
# Tour found with OR Tools: [0, 4, 5, 3, 6, 1, 2, 7]
# OR Tools Tour Cost: 29.9621
# Accuracy: 100
#
#
#
# Instance 18:
# locations:  [(3.119983302923325, 2.982736482575193), (4.239633018023618, 8.915526477562587), (8.97482108037472, 7.211881833820288), (5.523251913980003, 7.8605897649003955), (8.528922570238125, 5.080876743469702), (1.4157979349877547, 7.436292157969077), (6.488133472697807, 6.119239940234932), (5.274563097070567, 4.678072631564042), (5.041227694220202, 4.818048554444225)]
# Tour found with TD learning: [0, 8, 7, 6, 3, 1, 5, 4, 2]
# TD learning Tour Cost: 28.545907975778974
# Tour found with OR Tools: [0, 7, 8, 6, 5, 3, 1, 2, 4]
# OR Tools Tour Cost: 21.8883
# Accuracy: 69.5837137841725
#
#
#
# Instance 19:
# locations:  [(8.138109438657482, 0.5075741590167304), (5.1153686781516825, 3.6669182582581374), (8.58071638400946, 4.211893829535912), (2.627368128482618, 1.024747697853856), (9.728636292730222, 4.49183782798756), (8.535457855226205, 2.3702886654927333), (2.162703465193104, 6.820866544148455), (8.2864010046333, 2.1208623662168824), (4.088159910267382, 7.386277850233093)]
# Tour found with TD learning: [0, 7, 5, 2, 4, 1, 3, 6, 8]
# TD learning Tour Cost: 29.115818955860128
# Tour found with OR Tools: [0, 7, 5, 2, 4, 3, 6, 8, 1]
# OR Tools Tour Cost: 22.4566
# Accuracy: 70.34627256191888
#
#
#
# Instance 20:
# locations:  [(6.301518101254066, 9.08051404929097), (1.9058199874898274, 4.471182102518797), (6.463420207743246, 7.2561153249218275), (4.414915182797517, 6.059735291601696), (2.7692934880493434, 7.932307982917608), (1.5229293281886003, 6.97047228340479)]
# Tour found with TD learning: [0, 2, 3, 4, 5, 1]
# TD learning Tour Cost: 17.16885574758768
# Tour found with OR Tools: [0, 2, 4, 5, 1, 3]
# OR Tools Tour Cost: 18.3056
# Accuracy: 100
#
#
#
# Instance 21:
# locations:  [(8.289108984030602, 9.535845429881723), (3.7430297187851016, 7.46819215565551), (5.749309870521541, 3.7320251218939693), (8.932146531735095, 3.4773179179625844), (9.448723608369962, 5.276495068259677), (4.767457640268473, 1.6358964999156622), (6.964268467359849, 6.685191198301448), (7.612159738414837, 7.5711197225682625)]
# Tour found with TD learning: [0, 7, 6, 4, 3, 2, 5, 1]
# TD learning Tour Cost: 24.327021862740718
# Tour found with OR Tools: [0, 7, 6, 1, 2, 5, 3, 4]
# OR Tools Tour Cost: 23.5874
# Accuracy: 96.86433492991716
#
#
#
# Instance 22:
# locations:  [(1.813573774513969, 3.9181097533796905), (0.014072948147751951, 3.537194905006925), (3.9281405353765377, 0.9935099394429758), (6.912738653570491, 9.633023143575256), (0.524803966902978, 1.7946289438358665), (0.7707868641282323, 0.9303169085337537)]
# Tour found with TD learning: [0, 1, 4, 5, 2, 3]
# TD learning Tour Cost: 24.51147295478864
# Tour found with OR Tools: [0, 1, 4, 5, 3, 2]
# OR Tools Tour Cost: 24.2186
# Accuracy: 98.79071063237082
#
#
#
# Instance 23:
# locations:  [(7.482234936534107, 1.0039925197120414), (9.62812868046786, 0.04779064888771889), (9.163467380101519, 5.87418834419101), (0.3419127050169235, 8.154463873413999), (1.7735959696139192, 9.827686012019592), (0.01072016317367308, 3.2347197564902963)]
# Tour found with TD learning: [0, 1, 2, 4, 3, 5]
# TD learning Tour Cost: 31.50556904815627
# Tour found with OR Tools: [0, 1, 2, 4, 3, 5]
# OR Tools Tour Cost: 33.042
# Accuracy: 100
#
#
#
# Instance 24:
# locations:  [(8.511524327186859, 2.102213471272062), (6.715950206919291, 2.6189228942423757), (8.188967325149957, 3.138023895715889), (2.0340867635381144, 7.635996090112793), (2.938821737082854, 5.698987626841331), (2.3142117178140165, 1.3311562450473502), (1.8067985692019217, 0.49391828233763646), (7.327145963260248, 7.163855318118921)]
# Tour found with TD learning: [0, 2, 1, 7, 4, 3, 5, 6]
# TD learning Tour Cost: 28.181750279033707
# Tour found with OR Tools: [0, 2, 1, 5, 4, 6, 3, 7]
# OR Tools Tour Cost: 22.3514
# Accuracy: 73.91505552657236
#
#
#
# Instance 25:
# locations:  [(2.7085807305723386, 3.075471669550814), (5.203848785147151, 2.6297438260955843), (4.362885898877887, 0.06365667904331462), (1.1815755277580886, 4.309906548748704), (5.011487662805897, 5.843219121976095), (6.50562300941402, 1.3839654221569164), (9.46576059793397, 7.633261363574744), (2.5303461824947804, 0.4303966064832965), (9.66905937079398, 5.0007899339822535)]
# Tour found with TD learning: [0, 3, 7, 2, 5, 1, 4, 8, 6]
# TD learning Tour Cost: 31.00172166423459
# Tour found with OR Tools: [0, 1, 5, 8, 6, 4, 2, 7, 3]
# OR Tools Tour Cost: 23.3584
# Accuracy: 67.27805986610987
#
#
#
# Instance 26:
# locations:  [(8.769921362033568, 2.63915321540365), (8.880168018403792, 1.6280411753251744), (6.747990620120356, 0.08381371423274331), (6.15596090774583, 2.3069231410150683), (2.8615017734037607, 3.0431753368871215), (7.766327413374175, 2.0470452493484306), (0.9844357685668526, 4.800111532633807), (3.041120201225308, 5.090379618169476)]
# Tour found with TD learning: [0, 1, 5, 3, 2, 4, 7, 6]
# TD learning Tour Cost: 23.235835628003514
# Tour found with OR Tools: [0, 1, 2, 4, 6, 7, 3, 5]
# OR Tools Tour Cost: 23.7605
# Accuracy: 100
#
#
#
# Instance 27:
# locations:  [(8.214914837452191, 2.86992656257162), (8.959915532697424, 5.113760004125739), (7.665296001662542, 6.306340997038627), (7.1268546124528465, 2.9880671295009833), (1.19911086683536, 7.249543897828917)]
# Tour found with TD learning: [0, 3, 1, 2, 4]
# TD learning Tour Cost: 20.466747848696762
# Tour found with OR Tools: [0, 3, 4, 2, 1]
# OR Tools Tour Cost: 23.4008
# Accuracy: 100
#
#
#
# Instance 28:
# locations:  [(5.72553165566132, 0.20203446954270898), (4.889800338898114, 6.53870641774379), (3.2913598598709317, 9.28525837564788), (3.415837900611862, 7.109897740406042), (6.288110954190602, 7.196595936753026), (4.551286841729253, 9.298683915834088)]
# Tour found with TD learning: [0, 1, 4, 5, 2, 3]
# TD learning Tour Cost: 21.386355903152722
# Tour found with OR Tools: [0, 1, 4, 3, 5, 2]
# OR Tools Tour Cost: 23.6097
# Accuracy: 100
#
#
#
# Instance 29:
# locations:  [(9.390481377884985, 8.388481844221094), (5.241753010505395, 0.4137811879159581), (6.68781789717928, 3.69837246640515), (2.535294341625003, 8.268072503737642), (4.483769594032721, 9.15758759771276), (9.674815643039883, 4.3675713241373915), (8.34829952227988, 6.446411322765119)]
# Tour found with TD learning: [0, 6, 5, 2, 1, 3, 4]
# TD learning Tour Cost: 26.735967010178456
# Tour found with OR Tools: [0, 6, 5, 2, 1, 3, 4]
# OR Tools Tour Cost: 28.4184
# Accuracy: 100
#
#
#
# Instance 30:
# locations:  [(3.8769158738806544, 1.1342320836332298), (5.4413164237275256, 4.346937222114421), (9.52665264885227, 4.035800478006442), (0.4103025349952627, 5.690938506337879), (2.651713126399826, 7.212367658885421), (5.0694881056970456, 9.022227339072229), (6.8222921515485, 2.158477050264417)]
# Tour found with TD learning: [0, 6, 1, 4, 3, 5, 2]
# TD learning Tour Cost: 31.18118842082564
# Tour found with OR Tools: [0, 6, 1, 4, 2, 5, 3]
# OR Tools Tour Cost: 20.8582
# Accuracy: 50.5087283618642
#
#
#
# Instance 31:
# locations:  [(8.488168247773004, 6.980587019718443), (5.501093040884545, 6.078171098834209), (4.295688499444824, 3.8382057305725956), (7.5988554851274905, 2.9629287182860056), (8.552495048760866, 7.122078012111405), (6.3404721707956515, 0.5049381542253639), (3.9183764838070676, 0.22396057849619067), (1.4936436783695883, 7.7519813862315035)]
# Tour found with TD learning: [0, 4, 1, 2, 3, 5, 6, 7]
# TD learning Tour Cost: 29.48686562794793
# Tour found with OR Tools: [0, 4, 3, 5, 6, 7, 2, 1]
# OR Tools Tour Cost: 21.2004
# Accuracy: 60.913635459953895
#
#
#
# Instance 32:
# locations:  [(0.864527750208498, 7.965908277185008), (2.0047872384466556, 3.193150589069554), (6.550218921139772, 6.148596879108233), (6.113847628336564, 4.56991694339499), (9.684854214518081, 1.1729147724688083), (6.350695413700684, 4.596802591569384), (0.5105356476863687, 8.81511217765927), (7.698726970674539, 6.107673881531236), (5.7495610145663525, 9.604409444902027)]
# Tour found with TD learning: [0, 6, 8, 2, 7, 5, 3, 1, 4]
# TD learning Tour Cost: 36.5858350560089
# Tour found with OR Tools: [0, 6, 8, 4, 7, 2, 5, 3, 1]
# OR Tools Tour Cost: 30.3894
# Accuracy: 79.60988023452619
#
#
#
# Instance 33:
# locations:  [(5.425063092880821, 8.068131994808946), (3.0404697385022295, 4.972225910787492), (4.651870153795525, 4.670785846610698), (0.48786284187348206, 7.042957079540454), (3.979137664958605, 3.900439328422738), (6.529694789702736, 0.0327423163966345)]
# Tour found with TD learning: [0, 2, 4, 1, 3, 5]
# TD learning Tour Cost: 26.58410392767432
# Tour found with OR Tools: [0, 2, 1, 4, 3, 5]
# OR Tools Tour Cost: 21.8439
# Accuracy: 78.29964462539053
#
#
#
# Instance 34:
# locations:  [(9.196584671226205, 0.04192287740256706), (7.181571536503269, 3.91275707559977), (3.419716275455121, 7.760522484465373), (4.194783435164693, 5.580899076251347), (0.4059327014373504, 7.473269226933775), (6.132904910465782, 3.433646150562998), (3.582066129821534, 8.841078329452944), (1.991621088898804, 1.2930963584859556)]
# Tour found with TD learning: [0, 1, 5, 3, 2, 6, 4, 7]
# TD learning Tour Cost: 28.966710348931052
# Tour found with OR Tools: [0, 1, 5, 3, 2, 6, 4, 7]
# OR Tools Tour Cost: 28.9485
# Accuracy: 99.93709398092801
#
#
#
# Instance 35:
# locations:  [(0.03834111314754862, 9.715579269665563), (8.30620157919642, 4.405108504677702), (4.340993801065142, 3.5822227894837466), (6.797564713238393, 1.4081259655059197), (0.4476703403677551, 8.379664985573607), (0.4776033441708416, 2.9838411385653254), (5.4187548245278085, 2.30257565875715), (9.46345836054497, 7.309821219632424), (9.283133575641369, 3.342664789632349)]
# Tour found with TD learning: [0, 4, 5, 2, 6, 3, 8, 1, 7]
# TD learning Tour Cost: 31.46620873869574
# Tour found with OR Tools: [0, 4, 2, 1, 8, 3, 7, 6, 5]
# OR Tools Tour Cost: 31.8641
# Accuracy: 100
#
#
#
# Instance 36:
# locations:  [(4.846913193784968, 5.5355586155224525), (3.368133065436172, 2.0928173359687987), (2.676641929180964, 0.21364445366576335), (2.8308284854027264, 7.391594624928077), (3.8035135277119836, 8.892621502739535), (8.432463124449566, 3.3229355920028514), (3.4331673203965076, 3.2122257535553524), (4.6389314717968, 5.262122549142168), (0.8989642288121746, 1.2987130397536617)]
# Tour found with TD learning: [0, 7, 6, 1, 2, 8, 3, 4, 5]
# TD learning Tour Cost: 27.563976524770954
# Tour found with OR Tools: [0, 7, 6, 1, 2, 8, 5, 4, 3]
# OR Tools Tour Cost: 18.3682
# Accuracy: 49.93643076201831
#
#
#
# Instance 37:
# locations:  [(4.861338660618861, 1.7422928463795961), (1.7806416626725063, 3.3515318353307677), (7.636255558583132, 9.56278278023435), (7.931427188292409, 2.7965809297852973), (8.65252167756464, 8.692566104145564), (9.68433691256954, 5.6093433551590035), (2.9840734450514503, 1.5345237918281773)]
# Tour found with TD learning: [0, 6, 1, 3, 5, 4, 2]
# TD learning Tour Cost: 26.44558983647118
# Tour found with OR Tools: [0, 6, 1, 2, 4, 5, 3]
# OR Tools Tour Cost: 24.8078
# Accuracy: 93.39808513261482
#
#
#
# Instance 38:
# locations:  [(9.327839528544057, 6.402662154952063), (6.717301179937481, 7.788204645063938), (3.218403181113827, 5.510827673496391), (0.6401201240164611, 0.6108088485863927), (0.1979558952016458, 0.4465703918582642), (1.7121566026534563, 4.577304272001487), (1.4766357444868905, 4.741636494300786), (7.965248445745371, 6.256595772564578)]
# Tour found with TD learning: [0, 7, 1, 2, 5, 6, 3, 4]
# TD learning Tour Cost: 25.16734701224531
# Tour found with OR Tools: [0, 7, 1, 2, 5, 6, 4, 3]
# OR Tools Tour Cost: 29.7618
# Accuracy: 100
#
#
#
# Instance 39:
# locations:  [(1.8116143350605085, 4.711250020424929), (4.825893318050284, 2.405925712883926), (7.147750525134914, 0.33698097305712604), (6.648616039009871, 4.0488005266295035), (2.900263378717882, 7.412643925557853), (3.7986711255956607, 8.594221544375223)]
# Tour found with TD learning: [0, 4, 5, 3, 1, 2]
# TD learning Tour Cost: 22.225480853127976
# Tour found with OR Tools: [0, 4, 5, 2, 3, 1]
# OR Tools Tour Cost: 19.2466
# Accuracy: 84.52256059185531
#
#
#
# Instance 40:
# locations:  [(3.9266330638740046, 1.0697287938832556), (0.6844925159873871, 6.896930672462659), (3.4462139326945387, 8.795444001627924), (7.971794574581425, 8.331806759132363), (9.702825177764758, 0.5097966551718724), (1.3539248549033245, 2.72058753728588)]
# Tour found with TD learning: [0, 5, 1, 2, 3, 4]
# TD learning Tour Cost: 29.00161141478382
# Tour found with OR Tools: [0, 5, 1, 2, 3, 4]
# OR Tools Tour Cost: 28.7865
# Accuracy: 99.25273508490501
#
#
#
# Instance 41:
# locations:  [(0.34142873247947514, 9.034680626666615), (7.956263724261811, 8.817950990710111), (0.15226520111372266, 5.062693585957558), (2.33407063615092, 9.822564263133849), (1.726005474643758, 1.8129697569509085)]
# Tour found with TD learning: [0, 3, 2, 4, 1]
# TD learning Tour Cost: 27.982236084180105
# Tour found with OR Tools: [0, 3, 1, 4, 2]
# OR Tools Tour Cost: 27.7205
# Accuracy: 99.05580316307389
#
#
#
# Instance 42:
# locations:  [(3.8276411197581295, 9.658885841245437), (9.693011954332366, 3.005730749116331), (3.4833641449653365, 0.9642520082851114), (9.029723746097392, 4.313940759731815), (5.039693527192766, 7.887795056337113), (3.2366157852874675, 5.4298780503223165), (6.816873433180125, 6.155114836950181), (6.108013791340009, 0.5697825655613931), (3.0155123146218896, 0.9626480885898958)]
# Tour found with TD learning: [0, 4, 6, 3, 1, 7, 2, 8, 5]
# TD learning Tour Cost: 25.172645570221867
# Tour found with OR Tools: [0, 4, 6, 3, 1, 7, 2, 8, 5]
# OR Tools Tour Cost: 28.8248
# Accuracy: 100
#
#
#
# Instance 43:
# locations:  [(5.405095218218588, 6.476703303211874), (5.724356396776368, 4.742221762912827), (7.095738895955672, 3.3533503523436368), (0.17086046893564744, 9.341457770103931), (8.29178459598957, 0.5595321639475781), (8.503685017531508, 5.6874179439907735), (2.644513167140643, 2.997197054885856), (4.530248269816611, 6.459570912348696), (9.401703499912665, 1.6405930649843592)]
# Tour found with TD learning: [0, 7, 1, 2, 5, 8, 4, 6, 3]
# TD learning Tour Cost: 32.266321354865184
# Tour found with OR Tools: [0, 7, 5, 3, 4, 8, 6, 2, 1]
# OR Tools Tour Cost: 20.399
# Accuracy: 41.82400433910887
#
#
#
# Instance 44:
# locations:  [(0.1707987202279626, 8.593210208017993), (3.488108124720691, 3.8759456560826444), (3.6604103147614833, 0.954030473692189), (5.072942928931137, 2.075309337070097), (4.0327643651919045, 6.249975133671675), (0.1607888019739212, 9.069348907160084)]
# Tour found with TD learning: [0, 5, 4, 1, 3, 2]
# TD learning Tour Cost: 20.302333906709183
# Tour found with OR Tools: [0, 5, 2, 3, 1, 4]
# OR Tools Tour Cost: 21.4986
# Accuracy: 100
#
#
#
# Instance 45:
# locations:  [(6.185083789560098, 5.202823086914737), (0.33968936240932446, 2.855509522797006), (5.448333869553402, 7.720503286443323), (6.828534584319732, 6.047221059145992), (4.912862411955539, 6.748784154817306), (6.017515775027247, 4.357264555416172), (3.9258144575393317, 7.893144974706715), (0.2562134640198721, 6.774911781229987), (6.335196531768245, 5.056877970997485)]
# Tour found with TD learning: [0, 8, 5, 3, 4, 2, 6, 7, 1]
# TD learning Tour Cost: 21.589654723428755
# Tour found with OR Tools: [0, 8, 3, 2, 6, 7, 1, 4, 5]
# OR Tools Tour Cost: 21.1238
# Accuracy: 97.79464526539375
#
#
#
# Instance 46:
# locations:  [(7.448493933478508, 5.913364253605579), (3.522852969144905, 8.491068860479615), (3.989602725908589, 2.7493520636795212), (2.351937483146509, 0.7242250375679082), (5.872772486693165, 7.140403902936719), (3.7740907473503427, 9.064053796977841)]
# Tour found with TD learning: [0, 4, 1, 5, 2, 3]
# TD learning Tour Cost: 21.52939600432356
# Tour found with OR Tools: [0, 4, 1, 5, 3, 2]
# OR Tools Tour Cost: 23.0449
# Accuracy: 100
#
#
#
# Instance 47:
# locations:  [(7.281715142412227, 7.256245648410857), (7.808185157258148, 5.440210976416227), (1.81830381861118, 2.0397035118587095), (4.794576158585952, 8.994109359699147), (7.054916190782524, 7.174056116909676), (7.310429892014322, 2.230067556480353), (5.785895987628956, 3.760611145278543)]
# Tour found with TD learning: [0, 4, 1, 6, 5, 2, 3]
# TD learning Tour Cost: 23.014818505861754
# Tour found with OR Tools: [0, 4, 3, 2, 5, 6, 1]
# OR Tools Tour Cost: 20.9403
# Accuracy: 90.09317676508095
#
#
#
# Instance 48:
# locations:  [(1.277010459464235, 4.938949310869503), (8.069023031452634, 5.7033470234620385), (5.589373571856684, 8.855671753058758), (9.020630157547174, 3.4797824812269695), (7.670543817692876, 2.360392873499797)]
# Tour found with TD learning: [0, 2, 1, 3, 4]
# TD learning Tour Cost: 20.902623499102155
# Tour found with OR Tools: [0, 2, 4, 3, 1]
# OR Tools Tour Cost: 21.3897
# Accuracy: 100
#
#
#
# Instance 49:
# locations:  [(8.637047087451524, 5.838762380587283), (7.369200654635987, 5.818950295242814), (6.725810048600184, 8.84270680865809), (6.090476044353856, 1.333567947287897), (6.502648123309333, 8.240168085257682), (3.7616371033965157, 6.930983184921825), (6.11195873719544, 4.434669106161372), (1.965829870225887, 2.853494778083374), (0.7573527591219564, 4.539613738196843)]
# Tour found with TD learning: [0, 1, 6, 3, 7, 8, 5, 4, 2]
# TD learning Tour Cost: 23.78982318954198
# Tour found with OR Tools: [0, 1, 6, 4, 2, 5, 8, 7, 3]
# OR Tools Tour Cost: 21.1464
# Accuracy: 87.49941744437832
#
#
#
# Instance 50:
# locations:  [(7.340066050332687, 7.8145718000290465), (8.949341682409575, 1.0495156906433123), (4.101780303528962, 3.628258860390694), (0.4061203015110437, 6.66202993425907), (6.902465633300714, 6.175071839659799), (6.90697833696717, 7.683586628713057)]
# Tour found with TD learning: [0, 5, 4, 2, 3, 1]
# TD learning Tour Cost: 27.703598545194037
# Tour found with OR Tools: [0, 5, 3, 2, 1, 4]
# OR Tools Tour Cost: 28.4223
# Accuracy: 100
#
#
#
# Instance 51:
# locations:  [(4.762265642670918, 2.7554379093923242), (0.4264986424135375, 8.575788449390917), (4.954052517333328, 9.562171492595631), (3.343679799298317, 8.085601091852515), (3.7719655205151783, 7.335787543080597), (3.8076332361677734, 7.573215914294752), (3.890328406534792, 6.284371955271863), (6.014538613938537, 4.550575619649882), (6.861468577199216, 8.302606303641713)]
# Tour found with TD learning: [0, 7, 6, 4, 5, 3, 2, 8, 1]
# TD learning Tour Cost: 25.089259685220558
# Tour found with OR Tools: [0, 7, 8, 2, 1, 3, 5, 4, 6]
# OR Tools Tour Cost: 23.128
# Accuracy: 91.51997714795678
#
#
#
# Instance 52:
# locations:  [(1.67860104812382, 9.074048260283298), (3.9648915396498117, 7.309601769557466), (8.971804544257061, 6.893524235436189), (4.98832089774051, 6.271524621772333), (3.088442947436465, 0.7729208492264361)]
# Tour found with TD learning: [0, 1, 3, 2, 4]
# TD learning Tour Cost: 25.287209350553354
# Tour found with OR Tools: [0, 1, 3, 2, 4]
# OR Tools Tour Cost: 21.9481
# Accuracy: 84.78633981732654
#
#
#
# Instance 53:
# locations:  [(0.6738545770304805, 5.735448456802387), (5.660051823599288, 0.7591823470134407), (8.308889596082427, 8.368279377506484), (0.066364624928551, 0.9236942409238225), (5.340351047706684, 8.615531891605254), (9.141344592995765, 0.34137072063658014), (5.900790853870693, 2.36621055789501), (9.154404062383495, 0.6868201517998052)]
# Tour found with TD learning: [0, 3, 1, 6, 7, 5, 2, 4]
# TD learning Tour Cost: 32.61066780094327
# Tour found with OR Tools: [0, 3, 6, 1, 7, 5, 2, 4]
# OR Tools Tour Cost: 28.8493
# Accuracy: 86.96201363310975
#
#
#
# Instance 54:
# locations:  [(2.111384849345357, 8.818182775687104), (1.310106078933374, 1.8439867585468095), (6.802587577382916, 6.788602302702275), (7.233876371666801, 8.438448056185873), (9.036760191137374, 0.2669675056381271), (1.892759787256425, 3.1953877216730966), (1.5821698630106584, 5.696518410341679)]
# Tour found with TD learning: [0, 6, 5, 1, 2, 3, 4]
# TD learning Tour Cost: 35.62561734162551
# Tour found with OR Tools: [0, 6, 5, 1, 4, 3, 2]
# OR Tools Tour Cost: 31.3113
# Accuracy: 86.22121297542577
#
#
#
# Instance 55:
# locations:  [(7.847956603297062, 8.08043397922943), (4.378006506093181, 7.80246701851611), (0.27613310717110595, 1.4528645891658465), (4.65047745266029, 5.318898708939441), (9.19296154502697, 4.289205751522448), (1.125446816578607, 3.394378727724894), (5.063198403220164, 4.882394624631054)]
# Tour found with TD learning: [0, 1, 3, 6, 4, 5, 2]
# TD learning Tour Cost: 31.05121700667437
# Tour found with OR Tools: [0, 1, 3, 6, 5, 2, 4]
# OR Tools Tour Cost: 26.4673
# Accuracy: 82.68082877107084
#
#
#
# Instance 56:
# locations:  [(9.074896035447198, 5.037831691594155), (7.265206365359171, 9.367763960237355), (8.834473175402028, 5.789958130588433), (8.403774554483872, 2.085928696314854), (8.972661135243193, 0.21133640513782415)]
# Tour found with TD learning: [0, 2, 3, 4, 1]
# TD learning Tour Cost: 20.48478106724821
# Tour found with OR Tools: [0, 2, 1, 4, 3]
# OR Tools Tour Cost: 22.6426
# Accuracy: 100
#
#
#
# Instance 57:
# locations:  [(4.686080716714215, 4.4218498055689315), (5.452726854790014, 3.1731182204835218), (8.02546116274559, 9.411525553701846), (2.200716740199086, 2.8307133709526076), (0.8842830407768498, 0.4681665938450674), (0.841122048541918, 6.16161341541373), (4.074704166654581, 7.154139278779472), (0.4058688312160075, 7.328191760582911)]
# Tour found with TD learning: [0, 1, 3, 4, 5, 7, 6, 2]
# TD learning Tour Cost: 28.605756821885535
# Tour found with OR Tools: [0, 1, 3, 4, 2, 7, 5, 6]
# OR Tools Tour Cost: 18.5513
# Accuracy: 45.80187468325383
#
#
#
# Instance 58:
# locations:  [(3.5554441994621913, 8.226419671685829), (4.861932142744871, 8.201712046540313), (7.244948042787426, 2.1782530754337004), (4.800754284160416, 0.30075038279998245), (1.7725186969598827, 8.472277146632685)]
# Tour found with TD learning: [0, 1, 4, 2, 3]
# TD learning Tour Cost: 23.85332470261698
# Tour found with OR Tools: [0, 1, 2, 3, 4]
# OR Tools Tour Cost: 22.6334
# Accuracy: 94.6100687363941
#
#
#
# Instance 59:
# locations:  [(9.351548702157569, 7.6639720204644775), (5.071402041481371, 2.669253205179447), (5.466398163992197, 8.091562413886935), (4.086763719048201, 8.139287876195034), (2.103914057758345, 3.7363458410204444), (3.0655180901916177, 4.169215899257902), (0.5874448410541011, 7.5581430263354275), (2.0670488649049745, 7.250298620133257)]
# Tour found with TD learning: [0, 2, 3, 7, 6, 4, 5, 1]
# TD learning Tour Cost: 23.255717430946653
# Tour found with OR Tools: [0, 2, 3, 7, 6, 4, 5, 1]
# OR Tools Tour Cost: 25.9702
# Accuracy: 100
#
#
#
# Instance 60:
# locations:  [(5.441348574189306, 5.42457681177946), (4.30975120038949, 7.350317554337513), (0.30109190144717246, 2.5110113045191285), (6.881591650972382, 3.2593683134062577), (3.023701254968958, 4.23545897135959), (9.724872781025983, 2.1377924247581372), (0.06472352300160633, 0.30722459686754133), (9.877355266030236, 1.6010534053719705), (4.2830452725016315, 3.332528687413978)]
# Tour found with TD learning: [0, 1, 4, 8, 3, 5, 7, 2, 6]
# TD learning Tour Cost: 32.62560634365407
# Tour found with OR Tools: [0, 8, 3, 5, 7, 6, 2, 4, 1]
# OR Tools Tour Cost: 23.3104
# Accuracy: 60.038410565009315
#
#
#
# Instance 61:
# locations:  [(9.660464050869239, 6.298263697300043), (6.854309967976374, 1.3400467587093878), (3.9883384542295297, 0.8577042474292351), (6.812362551785968, 6.525476654019201), (5.4317195315705815, 9.342851377639322), (7.814769217858636, 2.4102707727084516), (2.5258558263966457, 7.000492000296333), (2.312072883580658, 3.236296709875175), (4.158582516687104, 4.839370804020855)]
# Tour found with TD learning: [0, 3, 4, 6, 8, 7, 2, 1, 5]
# TD learning Tour Cost: 26.4388899949087
# Tour found with OR Tools: [0, 3, 8, 5, 1, 2, 7, 6, 4]
# OR Tools Tour Cost: 27.0607
# Accuracy: 100
#
#
#
# Instance 62:
# locations:  [(9.868889406413238, 6.7445484157186595), (8.486084880510989, 6.157694842470822), (2.210517568618957, 2.6312454634150284), (4.242721459717159, 9.807913834092313), (9.974063687178878, 0.2896342182041256), (8.54423851593927, 8.492691071326524), (4.140311128633842, 3.134640939387233), (1.1835722892590406, 5.9499322881268135), (6.367205246233489, 3.682657428366536)]
# Tour found with TD learning: [0, 1, 5, 3, 7, 2, 6, 8, 4]
# TD learning Tour Cost: 32.429047182952566
# Tour found with OR Tools: [0, 1, 8, 6, 2, 7, 4, 3, 5]
# OR Tools Tour Cost: 23.1327
# Accuracy: 59.812960947262674
#
#
#
# Instance 63:
# locations:  [(7.640085126036168, 4.0638019227385165), (4.369845715653195, 3.243674576368518), (7.520473909168292, 9.44235002638954), (0.4729136394130429, 6.2496770344617545), (4.076297832404526, 8.395227378553841), (0.6551334523666386, 0.33740897792587377), (4.317709815893772, 1.2376021864543274)]
# Tour found with TD learning: [0, 1, 6, 5, 3, 4, 2]
# TD learning Tour Cost: 28.238404275801983
# Tour found with OR Tools: [0, 1, 6, 5, 3, 4, 2]
# OR Tools Tour Cost: 22.1166
# Accuracy: 72.32031923622083
#
#
#
# Instance 64:
# locations:  [(7.441800613022186, 1.339507563988328), (9.065537177423746, 9.848357557680249), (4.552047332385463, 5.020106373784724), (4.03184502219625, 6.577608796245712), (2.44245674600877, 8.49312097694118)]
# Tour found with TD learning: [0, 2, 3, 4, 1]
# TD learning Tour Cost: 24.2333060452236
# Tour found with OR Tools: [0, 2, 3, 4, 1]
# OR Tools Tour Cost: 28.395
# Accuracy: 100
#
#
#
# Instance 65:
# locations:  [(9.55399699862675, 3.9812857427337622), (4.083663318330113, 2.9680980682163973), (2.965557838538142, 1.810108276104061), (3.0155588300483984, 9.6823604819021), (0.7226291901724069, 2.2004373091568716)]
# Tour found with TD learning: [0, 1, 2, 4, 3]
# TD learning Tour Cost: 25.949961383355514
# Tour found with OR Tools: [0, 1, 2, 4, 3]
# OR Tools Tour Cost: 24.8834
# Accuracy: 95.71376345935236
#
#
#
# Instance 66:
# locations:  [(6.462380977814828, 3.387071143071779), (2.204651669588804, 4.827365043265673), (6.087238277666632, 7.293430903648335), (5.081016480849707, 4.381224317133549), (4.662922210615374, 9.71538162288198), (7.966595449511251, 8.420468104804943), (6.895195225521434, 4.207015089058961), (5.852555554080534, 8.628149207132843)]
# Tour found with TD learning: [0, 6, 3, 1, 2, 7, 4, 5]
# TD learning Tour Cost: 22.02856084320844
# Tour found with OR Tools: [0, 6, 2, 7, 5, 4, 1, 3]
# OR Tools Tour Cost: 21.0715
# Accuracy: 95.45803173381849
#
#
#
# Instance 67:
# locations:  [(0.13215395971866273, 3.9762841920333925), (6.833338683511353, 7.688494048849822), (7.353146397299172, 1.8097912653353143), (1.80082521832157, 2.226260294631489), (0.10662723392746543, 0.58783995792975)]
# Tour found with TD learning: [0, 3, 4, 2, 1]
# TD learning Tour Cost: 25.686080141152065
# Tour found with OR Tools: [0, 3, 1, 2, 4]
# OR Tools Tour Cost: 27.1014
# Accuracy: 100
#
#
#
# Instance 68:
# locations:  [(4.33480619590748, 2.3000819990024777), (8.180001778202099, 9.921978623888236), (2.227219878889335, 3.2692459762812796), (8.156555681537455, 4.164223871318002), (7.4798847013004615, 2.0998145247709066), (5.896036729618581, 2.849793550616452), (3.6693673756625644, 6.7701554357880545)]
# Tour found with TD learning: [0, 5, 4, 3, 6, 2, 1]
# TD learning Tour Cost: 32.01949927071294
# Tour found with OR Tools: [0, 2, 4, 3, 6, 1, 5]
# OR Tools Tour Cost: 25.3788
# Accuracy: 73.83367507245046
#
#
#
# Instance 69:
# locations:  [(8.542181109475049, 2.421082113930747), (1.7812853173382937, 2.3696416188212432), (4.379309764022171, 2.7392590045697887), (6.872581870945975, 5.860826562432808), (0.03979614451524505, 7.90358496041182), (7.488557822814426, 9.498077651698054)]
# Tour found with TD learning: [0, 3, 5, 2, 1, 4]
# TD learning Tour Cost: 33.494683597894564
# Tour found with OR Tools: [0, 3, 5, 4, 1, 2]
# OR Tools Tour Cost: 29.0441
# Accuracy: 84.67646235244142
#
#
#
# Instance 70:
# locations:  [(4.575245046260776, 8.377160850060596), (1.0570889164671826, 4.166338816873866), (3.2247061053173907, 8.702602127076824), (5.685746495406444, 8.078242125237148), (8.501015554814984, 0.18088907657564213)]
# Tour found with TD learning: [0, 3, 2, 1, 4]
# TD learning Tour Cost: 26.24820365459769
# Tour found with OR Tools: [0, 3, 4, 1, 2]
# OR Tools Tour Cost: 26.7014
# Accuracy: 100
#
#
#
# Instance 71:
# locations:  [(9.349462525675765, 4.477367141549432), (4.465544475347338, 7.287121852795904), (1.940894823475271, 0.23235787017468867), (5.701932593274135, 0.48838588003348615), (8.104757036004681, 3.6037725726283343), (1.397862942558702, 7.042031708019556)]
# Tour found with TD learning: [0, 4, 3, 2, 5, 1]
# TD learning Tour Cost: 24.768009739828422
# Tour found with OR Tools: [0, 4, 1, 5, 2, 3]
# OR Tools Tour Cost: 25.4682
# Accuracy: 100
#
#
#
# Instance 72:
# locations:  [(3.378655398892122, 2.9125435924684426), (5.211570616415076, 0.6888720571147522), (3.236576833860554, 7.175811561995805), (1.4742346990989075, 7.245221219359327), (1.6400518449221857, 9.352591898324418), (5.3029700802079605, 5.9794615173850545), (4.785880387224255, 4.577023114824951), (6.305549162086771, 7.861718685499016), (1.3824780561248973, 6.835871654981462)]
# Tour found with TD learning: [0, 6, 5, 7, 2, 3, 8, 4, 1]
# TD learning Tour Cost: 25.917468382582435
# Tour found with OR Tools: [0, 6, 5, 2, 8, 3, 4, 7, 1]
# OR Tools Tour Cost: 23.8051
# Accuracy: 91.12640407903166
#
#
#
# Instance 73:
# locations:  [(4.750159055153469, 0.8291095603832355), (3.3536580614914824, 2.9415328939854435), (6.906664466258975, 2.92364512586474), (4.698688666146861, 4.281763960992203), (1.55304376369376, 8.314212471902641)]
# Tour found with TD learning: [0, 1, 3, 2, 4]
# TD learning Tour Cost: 22.759937907523515
# Tour found with OR Tools: [0, 1, 3, 4, 2]
# OR Tools Tour Cost: 20.4301
# Accuracy: 88.59605235645682
#
#
#
# Instance 74:
# locations:  [(5.925705725476127, 3.83698744370383), (5.23977120002474, 6.324976774891031), (0.7279395638464625, 0.7297408893100454), (3.7248939302097392, 1.4764800660157162), (1.005365945215131, 3.876264074745721), (2.3451415221168217, 1.5840246818819836), (2.919866951377367, 3.7262905465741305), (1.3016476538598665, 3.8303396793984246)]
# Tour found with TD learning: [0, 1, 6, 7, 4, 5, 3, 2]
# TD learning Tour Cost: 21.16905056462724
# Tour found with OR Tools: [0, 3, 5, 2, 4, 7, 6, 1]
# OR Tools Tour Cost: 19.7365
# Accuracy: 92.74161799393387
#
#
#
# Instance 75:
# locations:  [(8.438797560102643, 2.836888212603262), (9.50860459007124, 3.7137798057272207), (6.881260742235393, 8.914271475052164), (8.29374614989757, 4.223468356505158), (6.900633440919, 6.894633197817407), (6.602858733072015, 6.086152694769673), (6.513080741313101, 4.4124812482703355)]
# Tour found with TD learning: [0, 1, 3, 6, 5, 4, 2]
# TD learning Tour Cost: 15.322559732388363
# Tour found with OR Tools: [0, 1, 3, 4, 2, 5, 6]
# OR Tools Tour Cost: 17.6243
# Accuracy: 100
#
#
#
# Instance 76:
# locations:  [(1.3991413208291181, 5.704802770918146), (4.016073434252842, 8.643563408944948), (5.832468701992593, 3.5490561986713063), (9.379357942516851, 9.207718810786588), (1.0005881894116064, 2.7961162587945387)]
# Tour found with TD learning: [0, 4, 2, 1, 3]
# TD learning Tour Cost: 27.34273870104363
# Tour found with OR Tools: [0, 4, 2, 3, 1]
# OR Tools Tour Cost: 22.8199
# Accuracy: 80.18028693796366
#
#
#
# Instance 77:
# locations:  [(8.606905168403433, 5.501792028263668), (7.253849643460999, 5.1880418766551015), (6.814438510384704, 0.32743586122269797), (4.0476875472445615, 7.7546692444854735), (3.1499809703451174, 2.0189439937664746)]
# Tour found with TD learning: [0, 1, 3, 4, 2]
# TD learning Tour Cost: 20.813506745134468
# Tour found with OR Tools: [0, 1, 3, 4, 2]
# OR Tools Tour Cost: 16.7848
# Accuracy: 75.99788650961305
#
#
#
# Instance 78:
# locations:  [(4.523572450135899, 9.357018446270953), (0.30829953726654424, 2.3407968655198785), (3.2952216757882837, 9.842874453734966), (5.418220156456509, 6.0125758652345755), (9.33444482305239, 6.857790668422372), (7.275341692975456, 9.093559499176934)]
# Tour found with TD learning: [0, 2, 5, 4, 3, 1]
# TD learning Tour Cost: 26.894302907232788
# Tour found with OR Tools: [0, 2, 3, 1, 4, 5]
# OR Tools Tour Cost: 28.2827
# Accuracy: 100
#
#
#
# Instance 79:
# locations:  [(8.826204741361922, 2.5925518081390564), (4.015264212443048, 4.69539782056978), (7.471411330672325, 4.017485273649451), (5.7349859649956105, 6.786655153314274), (7.93585384040583, 6.908942016581684), (6.827894486588493, 0.8248463789562599), (5.024086836583049, 9.51176056841264)]
# Tour found with TD learning: [0, 2, 4, 3, 1, 5, 6]
# TD learning Tour Cost: 31.358329733738643
# Tour found with OR Tools: [0, 2, 1, 3, 6, 4, 5]
# OR Tools Tour Cost: 21.6037
# Accuracy: 54.847411629773404
#
#
#
# Instance 80:
# locations:  [(2.953228998720532, 2.393793303097328), (2.8190381046244406, 2.975724161508422), (5.803409348968791, 2.4315701621059116), (2.290214184826984, 4.6299153396447545), (0.977131663410834, 3.3278542615742337), (0.9051476416313731, 9.937187780527307), (8.76816862176156, 9.020543096225296)]
# Tour found with TD learning: [0, 1, 3, 4, 2, 6, 5]
# TD learning Tour Cost: 32.04987927617519
# Tour found with OR Tools: [0, 1, 3, 5, 6, 2, 4]
# OR Tools Tour Cost: 24.6102
# Accuracy: 69.7699357332521
#
#
#
# Instance 81:
# locations:  [(6.944275710404816, 2.7094996550498287), (6.39757332868681, 2.1071823679568444), (8.947935754988288, 2.6868345237998206), (6.8561149998532365, 0.41440473342001405), (6.38042445720861, 0.15555114460910624), (6.87489333093901, 2.53054573543091)]
# Tour found with TD learning: [0, 5, 1, 3, 4, 2]
# TD learning Tour Cost: 8.73456899315833
# Tour found with OR Tools: [0, 5, 1, 3, 4, 2]
# OR Tools Tour Cost: 7.4199
# Accuracy: 82.28185025191269
#
#
#
# Instance 82:
# locations:  [(8.246053572627511, 9.549067922745731), (3.598512845625242, 0.15161963761793018), (4.752911441930139, 2.5037798030442704), (7.914302915716482, 1.2881223061572145), (3.7088808342483395, 5.18740451016754), (0.666887057808524, 3.364263707780848)]
# Tour found with TD learning: [0, 4, 2, 1, 5, 3]
# TD learning Tour Cost: 31.949104014173088
# Tour found with OR Tools: [0, 4, 2, 1, 5, 3]
# OR Tools Tour Cost: 31.0627
# Accuracy: 97.14640384070577
#
#
#
# Instance 83:
# locations:  [(6.332105852975397, 8.133516609714384), (8.160513252422314, 5.123201585639308), (7.935608508420971, 3.5680843896159855), (2.104336727739776, 5.389833234641914), (7.034006935545118, 5.049588686827736), (5.410351066058149, 5.9626620256281395), (9.31917527243283, 1.9776111621558634), (5.825530537408053, 1.1748607987187287)]
# Tour found with TD learning: [0, 5, 4, 1, 2, 6, 7, 3]
# TD learning Tour Cost: 23.2767513750538
# Tour found with OR Tools: [0, 5, 4, 1, 2, 6, 7, 3]
# OR Tools Tour Cost: 19.6041
# Accuracy: 81.26590164785019
#
#
#
# Instance 84:
# locations:  [(4.78973040367094, 5.680346848033798), (2.815696319122578, 2.994287428641611), (1.7430776617702604, 1.3391127671294112), (4.095894918231897, 4.690136065756415), (3.8579085893902754, 6.277603832206667)]
# Tour found with TD learning: [0, 4, 3, 1, 2]
# TD learning Tour Cost: 12.11277594111815
# Tour found with OR Tools: [0, 4, 2, 1, 3]
# OR Tools Tour Cost: 13.0616
# Accuracy: 100
#
#
#
# Instance 85:
# locations:  [(0.14949068760097606, 8.055961480622504), (8.837254473181964, 9.355029295697626), (2.937312330481412, 6.918874298432495), (5.077955425365293, 7.009652688547261), (0.4975017195853815, 5.395656170076179), (9.732392017556066, 4.204930553597073), (7.448446281340724, 3.03870105040021), (1.841704369353866, 3.1536055195961374)]
# Tour found with TD learning: [0, 4, 7, 2, 3, 1, 5, 6]
# TD learning Tour Cost: 32.44087310414381
# Tour found with OR Tools: [0, 4, 7, 6, 5, 1, 3, 2]
# OR Tools Tour Cost: 29.7342
# Accuracy: 90.89710466686908
#
#
#
# Instance 86:
# locations:  [(2.7632492780648743, 4.895626551430004), (6.058138940606056, 9.707968387037557), (6.4721701054608065, 7.349795342222175), (1.5983283617358879, 8.396354531400734), (8.6981004243768, 2.1715452612222164)]
# Tour found with TD learning: [0, 3, 1, 2, 4]
# TD learning Tour Cost: 22.89895792698048
# Tour found with OR Tools: [0, 3, 2, 1, 4]
# OR Tools Tour Cost: 23.9106
# Accuracy: 100
#
#
#
# Instance 87:
# locations:  [(2.3641688155828424, 2.1227996838517624), (0.7071668897960504, 2.7054860670154044), (1.3077804276278193, 0.9428788851435388), (8.03803455516406, 3.1258939514270114), (9.738382827513473, 6.093116093530426), (9.17047223497417, 8.74099177049471), (6.997472636162567, 0.780477742120278), (9.202307708509371, 9.410991778360104), (3.2215675352293105, 6.294679792728266)]
# Tour found with TD learning: [0, 2, 1, 8, 3, 6, 4, 5, 7]
# TD learning Tour Cost: 35.51016242716392
# Tour found with OR Tools: [0, 1, 8, 7, 5, 4, 3, 6, 2]
# OR Tools Tour Cost: 30.1607
# Accuracy: 82.26346726977847
#
#
#
# Instance 88:
# locations:  [(2.367338767305581, 2.2631925968044575), (6.661734316597396, 0.7186339050113766), (2.0867793525532905, 9.462457119285082), (2.5223004119987213, 4.526612022461488), (2.800754449176208, 2.0419594412916275), (4.241208207184409, 1.772858362582882)]
# Tour found with TD learning: [0, 4, 5, 1, 3, 2]
# TD learning Tour Cost: 22.37643364908529
# Tour found with OR Tools: [0, 4, 5, 1, 2, 3]
# OR Tools Tour Cost: 25.6834
# Accuracy: 100
#
#
#
# Instance 89:
# locations:  [(4.5729800197036505, 1.0510656481806646), (2.4411299495885865, 3.49306151476935), (0.21871158769349752, 5.671284488284977), (0.7949625261588678, 5.937638008600304), (8.454842156202568, 7.0302990047038065), (2.1310997317807834, 2.8615212112490185), (5.112335487743765, 1.582226249119627), (5.74419648977752, 6.9927882032299955), (0.955350381539094, 7.8437894150128615)]
# Tour found with TD learning: [0, 6, 5, 1, 3, 2, 8, 7, 4]
# TD learning Tour Cost: 25.28424906155168
# Tour found with OR Tools: [0, 6, 7, 4, 8, 2, 3, 1, 5]
# OR Tools Tour Cost: 22.2299
# Accuracy: 86.2601763320947
#
#
#
# Instance 90:
# locations:  [(2.348060715403001, 4.568056340494336), (2.6503848154234575, 8.398799559843994), (5.688759457135879, 0.9957681399223717), (2.2247663938786277, 4.968072638046489), (6.166621393556468, 2.283324740022427)]
# Tour found with TD learning: [0, 3, 1, 4, 2]
# TD learning Tour Cost: 17.19423519867324
# Tour found with OR Tools: [0, 3, 1, 4, 2]
# OR Tools Tour Cost: 19.9811
# Accuracy: 100
#
#
#
# Instance 91:
# locations:  [(7.587579689094572, 8.965695262215496), (0.5939435674156468, 6.3651178798614545), (9.485262089145557, 9.0151717753707), (3.4065201362148976, 4.767719711473898), (4.790368221257334, 7.084882970536689), (7.36823519474731, 8.866440324330977), (7.366068035057808, 6.124566846242962), (8.536081845840567, 7.530195586966072)]
# Tour found with TD learning: [0, 5, 7, 2, 6, 4, 3, 1]
# TD learning Tour Cost: 23.505919339584352
# Tour found with OR Tools: [0, 5, 4, 1, 3, 6, 7, 2]
# OR Tools Tour Cost: 24.4017
# Accuracy: 100
#
#
#
# Instance 92:
# locations:  [(9.546927260159181, 3.9345364191739343), (9.643424790830714, 2.527333908440946), (2.72032287621355, 6.496861207449181), (1.3050332169425383, 9.859723754650577), (7.171862238162595, 3.888532648314519), (8.155729565712459, 8.449216076225216), (0.38598887786513325, 0.4075195083908889), (8.003860372093387, 3.269328743846389), (0.9760551231818704, 9.950236454093288)]
# Tour found with TD learning: [0, 1, 7, 4, 5, 2, 3, 8, 6]
# TD learning Tour Cost: 38.05542889895411
# Tour found with OR Tools: [0, 1, 6, 8, 3, 2, 5, 4, 7]
# OR Tools Tour Cost: 31.5567
# Accuracy: 79.40618347623764
#
#
#
# Instance 93:
# locations:  [(3.9577935081983218, 3.040306278032615), (5.962428541778619, 7.908264624636536), (0.17848478662338962, 6.624085826360226), (2.56017919618294, 3.5537732175849), (4.628784505627472, 4.335839892520054), (3.1002059392283075, 0.2786674844139836), (2.0937374840945377, 0.6281707460479646), (1.2550079289507354, 0.5073494672382461)]
# Tour found with TD learning: [0, 4, 3, 6, 7, 5, 2, 1]
# TD learning Tour Cost: 27.514848165867125
# Tour found with OR Tools: [0, 4, 1, 2, 7, 6, 5, 3]
# OR Tools Tour Cost: 22.1001
# Accuracy: 75.49898794183228
#
#
#
# Instance 94:
# locations:  [(2.243816186567397, 3.7272147289775903), (3.07392246885301, 3.083893599745391), (3.3974181331454, 9.428350616728503), (8.82193349439858, 6.049030658203255), (4.70171253860426, 2.5517830872595573), (7.472026076547122, 4.20388983388683), (1.8999657185952012, 7.445347778705955), (9.126448534160934, 4.450411102883411)]
# Tour found with TD learning: [0, 1, 4, 5, 7, 3, 2, 6]
# TD learning Tour Cost: 21.898261764706007
# Tour found with OR Tools: [0, 1, 4, 5, 7, 3, 2, 6]
# OR Tools Tour Cost: 19.3345
# Accuracy: 86.73996346062216
#
#
#
# Instance 95:
# locations:  [(1.4273842870159936, 8.66500933410975), (4.666942004313162, 2.3038492218857876), (9.540563866486153, 9.878822558611054), (3.226457157680427, 1.3825728224185985), (0.17099505614171617, 4.9561214332575645), (7.3659496648364255, 4.445998323730103), (8.002785603914498, 9.4986697071588)]
# Tour found with TD learning: [0, 4, 3, 1, 5, 6, 2]
# TD learning Tour Cost: 28.653500163645642
# Tour found with OR Tools: [0, 4, 1, 3, 5, 2, 6]
# OR Tools Tour Cost: 28.2126
# Accuracy: 98.43722250467648
#
#
#
# Instance 96:
# locations:  [(9.45441822945154, 7.95022084701278), (9.730115814892608, 1.5469367873536055), (2.457498740764512, 0.8212518326189167), (9.757801255526674, 7.576923093967586), (9.500961887443513, 0.6099477635160633)]
# Tour found with TD learning: [0, 3, 1, 4, 2]
# TD learning Tour Cost: 24.51126606569818
# Tour found with OR Tools: [0, 3, 1, 4, 2]
# OR Tools Tour Cost: 27.3132
# Accuracy: 100
#
#
#
# Instance 97:
# locations:  [(2.3103105970395346, 2.536909559630188), (2.236069787997743, 9.717351561152363), (4.2608298972461895, 6.537893162074005), (3.981175442720186, 0.05397322021846618), (1.0979914859121465, 1.1726326175028845), (0.9634880410994151, 7.489849592123844)]
# Tour found with TD learning: [0, 4, 3, 2, 5, 1]
# TD learning Tour Cost: 24.585863279889015
# Tour found with OR Tools: [0, 4, 3, 1, 5, 2]
# OR Tools Tour Cost: 24.9479
# Accuracy: 100
#
#
#
# Instance 98:
# locations:  [(5.5536946268378005, 3.11823960383533), (6.525286071913298, 5.1468804669958645), (5.591134187013621, 2.190487860583344), (9.575018635326806, 9.117640257458875), (7.419974281485645, 2.9160767220813733), (4.317640253828497, 2.4215793790376905), (2.434964871019012, 3.560271659123625)]
# Tour found with TD learning: [0, 2, 5, 6, 1, 4, 3]
# TD learning Tour Cost: 25.00162347081217
# Tour found with OR Tools: [0, 2, 5, 6, 3, 1, 4]
# OR Tools Tour Cost: 19.3304
# Accuracy: 70.66163415753337
#
#
#
# Instance 99:
# locations:  [(2.2483422847955814, 0.20290158344622222), (9.509050184602003, 3.8423820546836596), (3.8234078349026057, 7.836445561456818), (0.5643275706849205, 2.27652425741685), (6.23572833951881, 6.685098114590502)]
# Tour found with TD learning: [0, 3, 2, 4, 1]
# TD learning Tour Cost: 24.24620231528116
# Tour found with OR Tools: [0, 3, 2, 4, 1]
# OR Tools Tour Cost: 26.8579
# Accuracy: 100
#
#
#
# Instance 100:
# locations:  [(1.9694074136257267, 0.8361364791611836), (6.113885958108143, 4.8790867521416), (5.3247998740485025, 8.206404279528641), (1.2923118750423623, 9.515340419568037), (0.38025799177403674, 7.640644345580631), (0.2029024841426985, 6.821616280719836)]
# Tour found with TD learning: [0, 1, 2, 3, 4, 5]
# TD learning Tour Cost: 22.612553543720246
# Tour found with OR Tools: [0, 5, 4, 3, 2, 1]
# OR Tools Tour Cost: 24.4032
# Accuracy: 100
#
# Average Percent Accuracy: 87.42661860562359
